# %% [markdown]
# # Scraping

# %% [markdown]
# ### import library

# %%
_= !pip install PyPDF2
from bs4 import BeautifulSoup, Tag
import requests
import PyPDF2
import re
import pandas as pd
import zipfile
import os

# %% [markdown]
# ### scraping direktory page

# %%
def scraping_putusan(url, filename):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        putusan_hukum = soup.find_all('div', class_='spost clearfix')

        putusan_text = []
        putusan_filename = []
        putusan_meta = []

        # Mendapatkan setiap keputusan dari halaman
        for i in putusan_hukum:
            tag = i.find_all('strong')
            for y in tag:
                if y.find('a'):
                    result = get_data(y.find('a').get('href'))
                    if result:
                        [pdf_name, get_data_text, meta_info] = result
                        if meta_info:
                            putusan_text.append(get_data_text)
                            putusan_filename.append(pdf_name)
                            putusan_meta.append(meta_info)

        # Memeriksa jika ada halaman berikutnya
        buttons = soup.find_all('ul', class_='pagination justify-content-center')
        for button in buttons:
            tag_a = button.find_all('a')
            for link in tag_a:
                if link.text.strip() == 'Next':
                    return (putusan_filename, putusan_text, putusan_meta, link.get('href'))

    else:
        print("Gagal mengakses halaman web. Kode status:", response.status_code)

# %% [markdown]
# ### scraping decision page

# %%
def get_data(url):
    response = requests.get(url)
    if response.status_code == 200:
        soup = BeautifulSoup(response.text, 'html.parser')
        box_lampiran = soup.find_all('ul', class_='portfolio-meta nobottommargin')[1]

        # Cek apakah ada tautan PDF di dalam lampiran
        if box_lampiran.find_all('a'):
            link_pdf = box_lampiran.find_all('a')[1]
            response_pdf = requests.get(link_pdf.get('href'))

            # Mengunduh file PDF jika tautan tersedia
            if response_pdf.status_code == 200:
                pdf_name = link_pdf.text.strip().replace('/', '_')
                with open(pdf_name, 'wb') as pdf_file:
                    pdf_file.write(response_pdf.content)
                print(f"File PDF '{pdf_name}' berhasil diunduh.")

                meta_info = generate_meta_info(soup, url)
                if meta_info:
                    meta_info.append(link_pdf.get('href'))
                print(f"Meta Info '{pdf_name}' berhasil dibuat.")
                return pdf_name, read_pdf(pdf_name), meta_info

            else:
                print("Gagal mengunduh file PDF. Kode status:", response.status_code)
                return False
        else:
            print('Link Download Tidak Tersedia')
            return False

# %% [markdown]
# ### get metadata from decision page

# %%
def generate_meta_info(soup, url):
    # Daftar elemen metadata yang akan diekstraksi
    listMetaHead = ["url_page", "penuntut_umum", "terdakwa", "nomor", "kata_kunci", "tahun", "tanggal_register",
                    "lembaga_peradilan", "hakim_ketua", "hakim_anggota", "panitera", "amar", "amar_lainnya",
                    "catatan_amar", "tanggal_musyawarah", "tanggal_dibacakan"]

    listMeta = [""] * len(listMetaHead)
    listMeta[0] = url

    # Mencari tabel metadata dalam halaman
    rowsMETA = soup.find("ul", {"class": "portfolio-meta nobottommargin"}).find("table").findAll("tr")
    for i, row in enumerate(rowsMETA):
        coll = row.findAll("td")
        if len(coll) > 1:
            # Menyesuaikan nama kolom untuk mencocokkan dengan listMetaHead
            formatted_coll_0 = clean_html_tags(str(coll[0])).lower().replace(" ", "_")
            index_in_listMetaHead = next((index for index, item in enumerate(listMetaHead) if item.lower() == formatted_coll_0), None)

            if index_in_listMetaHead is not None:
                cleantext = clean_html_tags(str(coll[1]))
                listMeta[index_in_listMetaHead] = cleantext
        else:
            h2_element = coll[0].find('h2')
            if h2_element and isinstance(h2_element, Tag):
                # Mengolah teks di dalam elemen H2 untuk mendapatkan informasi Penuntut Umum dan Terdakwa
                text_h = re.sub(r'<\/?br\/?>|<\/?strong\/?>', ' ', ' '.join(str(i) for i in h2_element))
                text_h = re.sub(r'\s+', ' ', text_h).strip()
                print(url)
                data = re.search(r'Penuntut Umum: (.+?) Terdakwa: (.+?)?(?=$|\s—)', text_h)
                if data:
                    Penuntun_Umum = data.group(1)
                    Terdakwa = data.group(2)

                    listMeta[1] = Penuntun_Umum
                    listMeta[2] = Terdakwa

    return listMeta

# %% [markdown]
# ### cleaning text from html tags and unused conversion results

# %%
def clean_text(text):
    # Menghapus teks header dan disclaimer yang berulang dari dokumen
    text = text.replace("Mahkamah Agung Republik Indonesia\nMahkamah Agung Republik Indonesia\nMahkamah Agung Republik Indonesia\nMahkamah Agung Republik Indonesia\nMahkamah Agung Republik Indonesia\nDirektori Putusan Mahkamah Agung Republik Indonesia\nputusan.mahkamahagung.go.id\n", "")
    text = text.replace("\nDisclaimer\nKepaniteraan Mahkamah Agung Republik Indonesia berusaha untuk selalu mencantumkan informasi paling kini dan akurat sebagai bentuk komitmen Mahkamah Agung untuk pelayanan publik, transparansi dan akuntabilitas\npelaksanaan fungsi peradilan. Namun dalam hal-hal tertentu masih dimungkinkan terjadi permasalahan teknis terkait dengan akurasi dan keterkinian informasi yang kami sajikan, hal mana akan terus kami perbaiki dari waktu kewaktu.\nDalam hal Anda menemukan inakurasi informasi yang termuat pada situs ini atau informasi yang seharusnya ada, namun belum tersedia, maka harap segera hubungi Kepaniteraan Mahkamah Agung RI melalui :\nEmail : kepaniteraan@mahkamahagung.go.id", "")
    text = text.replace("Telp : 021-384 3348 (ext.318)", "")
    # Menghapus nomor halaman dan elemen unik
    text = re.sub(r'\nHalaman \d+ dari \d+ .*', '', text)
    text = re.sub(r'Halaman \d+ dari \d+ .*', '', text)
    text = re.sub(r'\nHal. \d+ dari \d+ .*', '', text)
    text = re.sub(r'Hal. \d+ dari \d+ .*', '', text)
    text = re.sub(r' +|[\uf0fc\uf0a7\uf0a8\uf0b7]', ' ', text) # Menghapus bullet points dan spasi berlebih
    text = re.sub(r'[\u2026]+|\.{3,}', '', text) # Menghapus elipsis atau titik berulang
    return text.strip() # Menghapus spasi di awal dan akhir

# %%
def clean_html_tags(text):
    # Menghapus semua tag HTML dari teks
    clean_tags = re.compile('<.*?>')
    return re.sub(clean_tags, '', text).strip()

# %% [markdown]
# ### save documents and convert to text

# %%
def read_pdf(file_pdf):
    try:
        pdf_text = ''
        pdf_file = open(file_pdf, 'rb')
        pdf_reader = PyPDF2.PdfReader(pdf_file)

        # Membaca setiap halaman dan membersihkan teks
        for page_num in range(len(pdf_reader.pages)):
            page = pdf_reader.pages[page_num]
            text = clean_text(page.extract_text())
            pdf_text += ' ' + text

        pdf_file.close()
        return pdf_text.strip() # Mengembalikan teks bersih

    except requests.exceptions.RequestException as e:
        print("Error:", e)

# %%
def zip_dokumen(filename, listData):
    # Membuat file zip dan menambahkan setiap dokumen
    with zipfile.ZipFile(filename, "w", zipfile.ZIP_DEFLATED) as zipf:
        for file in listData:
            file_path = os.path.join('/content', file)
            zipf.write(file_path, os.path.basename(file_path))

    print(f"File {filename} berhasil diciptakan.")

# %% [markdown]
# ### scraping implementation

# %%
PATH = '/content/drive/MyDrive/Skripsi/Code/Data/'
url = 'https://putusan3.mahkamahagung.go.id/search.html?q=&jenis_doc=putusan&cat=6f5068aaa5515f46e4aeafca2f48dfa2&jd=&tp=&court=098413PN310+++++++++++++++++++++&t_put=&t_reg=&t_upl=&t_pr=' #bangkalan
filename = f"data_bkl.csv"

putusan_file = []
putusan_text = []
putusan_meta = []
next_button = url

for page in range(1,2):
  print(f"============== Page {page} ==============")
  result = scraping_putusan(next_button,filename)
  [putusan_file_new, putusan_text_new, putusan_meta_new, next_button_new] = result
  putusan_file += putusan_file_new
  putusan_text += putusan_text_new
  putusan_meta += putusan_meta_new
  next_button = next_button_new

print(f'Berhasil mengunduh sebanyak {len(putusan_text)} File')

# Menyimpan Datset Dalam Bentuk CSV
df_meta = pd.DataFrame(putusan_meta, columns=["url_page", "penuntut_umum", "terdakwa", "nomor", "kata_kunci", "tahun", "tanggal_register",
                  "lembaga_peradilan", "hakim_ketua", "hakim_anggota", "panitera", "amar", "amar_lainnya",
                  "catatan_amar", "tanggal_musyawarah", "tanggal_dibacakan", "url_pdf"])
df_file = pd.DataFrame(putusan_file, columns=['nama_file'])
df_text = pd.DataFrame(putusan_text, columns=['content'])
df_concat = pd.concat([df_meta, df_file, df_text], axis=1)
df_concat.to_csv(f'{PATH}{filename}', index=False)

print(f'Berhasil menyimpan ke dalam file {filename}')
zip_dokumen(f'{PATH}dokumen_bkl.zip', putusan_file)
# Out:
# ============== Page 1 ==============
# Link Download Tidak Tersedia
# Link Download Tidak Tersedia
# Link Download Tidak Tersedia
# Link Download Tidak Tersedia
# File PDF '194_Pid.C_2020_PN_Bkl.pdf' berhasil diunduh.
# https://putusan3.mahkamahagung.go.id/direktori/putusan/aa90168531e4110f46290049e9f3b23d.html
# Meta Info '194_Pid.C_2020_PN_Bkl.pdf' berhasil dibuat.
# File PDF '226_PID.B_2015_PN_Bkl.pdf' berhasil diunduh.
# https://putusan3.mahkamahagung.go.id/direktori/putusan/4c97584c77424ef13ac7b95b60d37f0c.html
# Meta Info '226_PID.B_2015_PN_Bkl.pdf' berhasil dibuat.
# Link Download Tidak Tersedia
# Link Download Tidak Tersedia
# Link Download Tidak Tersedia
# File PDF '70_Pid.C_2021_PN_Bkl.pdf' berhasil diunduh.
# https://putusan3.mahkamahagung.go.id/direktori/putusan/zaeb764b2b7dc2c2ab68303935313138.html
# Meta Info '70_Pid.C_2021_PN_Bkl.pdf' berhasil dibuat.
# File PDF '2_Pid.C_2019_PN_Bkl.pdf' berhasil diunduh.
# https://putusan3.mahkamahagung.go.id/direktori/putusan/d8c996748aff5fbcc64b307c3ebdfdb1.html
# Meta Info '2_Pid.C_2019_PN_Bkl.pdf' berhasil dibuat.
# File PDF '2_Pid.C_2020_PN_Bkl.pdf' berhasil diunduh.
# https://putusan3.mahkamahagung.go.id/direktori/putusan/11f168435550095775586e95cbacfedb.html
# Meta Info '2_Pid.C_2020_PN_Bkl.pdf' berhasil dibuat.
# Link Download Tidak Tersedia
# File PDF '3_Pid.C_2019_PN_Bkl.pdf' berhasil diunduh.
# https://putusan3.mahkamahagung.go.id/direktori/putusan/7f85ed23be37fc8b464b219639ee4b0e.html
# Meta Info '3_Pid.C_2019_PN_Bkl.pdf' berhasil dibuat.
# Link Download Tidak Tersedia
# Link Download Tidak Tersedia
# Link Download Tidak Tersedia
# File PDF '123_Pid.C_2021_PN_Bkl.pdf' berhasil diunduh.
# https://putusan3.mahkamahagung.go.id/direktori/putusan/zaeb90fd3d8f61f6aff9303931313239.html
# Meta Info '123_Pid.C_2021_PN_Bkl.pdf' berhasil dibuat.
# File PDF '21_Pid.C_2021_PN_Bkl.pdf' berhasil diunduh.
# https://putusan3.mahkamahagung.go.id/direktori/putusan/zaeb5ec1e45d78f69330313130303431.html
# Meta Info '21_Pid.C_2021_PN_Bkl.pdf' berhasil dibuat.
# File PDF '346_Pid.B_2017_PN_Bkl.pdf' berhasil diunduh.
# https://putusan3.mahkamahagung.go.id/direktori/putusan/23f90cccd1f70eff4eeb551ccce53b0a.html
# Meta Info '346_Pid.B_2017_PN_Bkl.pdf' berhasil dibuat.
# Berhasil mengunduh sebanyak 9 File
# Berhasil menyimpan ke dalam file data_bkl_try.csv
# File /content/drive/MyDrive/Skripsi/Code/Data/dokumen_bkl_try.zip berhasil diciptakan.

# %%
PATH = '/content/drive/MyDrive/Skripsi/Code/Data'
# data_bkl = pd.read_csv(f"{PATH}/data_pn_bkl.csv")
# data_spg = pd.read_csv(f"{PATH}/data_pn_spg.csv")
# data_pmk = pd.read_csv(f"{PATH}/data_pn_pmk.csv")
# data_smp = pd.read_csv(f"{PATH}/data_pn_smp.csv")
# data = pd.concat([data_bkl, data_spg, data_pmk, data_smp], ignore_index=True)
# data.to_csv(f"{PATH}/data_all.csv", index=False)
data = pd.read_csv(f"{PATH}/data_all.csv")
data
# Out:
#                                               url_page  \
# 0    https://putusan3.mahkamahagung.go.id/direktori...
# 1    https://putusan3.mahkamahagung.go.id/direktori...
# 2    https://putusan3.mahkamahagung.go.id/direktori...
# 3    https://putusan3.mahkamahagung.go.id/direktori...
# 4    https://putusan3.mahkamahagung.go.id/direktori...
# ..                                                 ...
# 744  https://putusan3.mahkamahagung.go.id/direktori...
# 745  https://putusan3.mahkamahagung.go.id/direktori...
# 746  https://putusan3.mahkamahagung.go.id/direktori...
# 747  https://putusan3.mahkamahagung.go.id/direktori...
# 748  https://putusan3.mahkamahagung.go.id/direktori...
#
#                        penuntut_umum                                 terdakwa  \
# 0              DEWI IKA AGUSTINA, SH                       TISLAN bin MUKAMAR
# 1    NANDINI PARAHITA YULISANI, S.H.                         BEIRI Bin BUNALI
# 2                 UMU LATHIEFAH, S.H                       FANDI bin SULAIMAN
# 3               FAJRINI FAISAH, S.H.                          PANDI Bin SIDIK
#                        nama_file  \
# 0       48_Pid.B_2024_PN_Bkl.pdf
# 1       42_Pid.B_2024_PN_Bkl.pdf
# 2       49_Pid.B_2024_PN_Bkl.pdf
# 3       56_Pid.B_2024_PN_Bkl.pdf
# 4       57_Pid.B_2024_PN_Bkl.pdf
# ..                           ...
# 744  274_Pid.Sus_2021_PN_Smp.pdf
# 745    272_Pid.B_2021_PN_Smp.pdf
# 746  220_Pid.Sus_2021_PN_Smp.pdf
# 747    293_Pid.B_2021_PN_Smp.pdf
# 748    254_Pid.B_2021_PN_Smp.pdf
#
#                                                content
# 0    PUTUSAN\nNomor 48/Pid.B/2024/PN Bkl\nDEMI KEAD...
# 1    PUTUSAN\nNomor 42/Pid.B/2024/PN Bkl\nDEMI KEAD...
# 2    PUTUSAN\nNomor 49/Pid.B/2024/PN Bkl\nDEMI KEAD...
# 3    PUTUSAN\nNomor 56/Pid.B/2024/PN Bkl\nDEMI KEAD...
# 4    PUTUSAN\nNomor 57/Pid.B/2024/PN Bkl\nDEMI KEAD...
# ..                                                 ...
# 744  PUTUSAN \nNomor 274/Pid.Sus/2021/PN Smp \n \nD...
# 745  PUTUSAN \nNomor 272/Pid.B/2021/PN Smp \n \nDEM...
# 746  PUTUSAN \nNomor 220/Pid.Sus/2021/PN Smp \n \nD...
# 747  PUTUSAN \nNomor 293/Pid.B/2021/PN Smp \n \nDEM...
# 748  PUTUSAN \nNomor 254/Pid.B/2021 /PN Smp \n \nDE...
#
# [749 rows x 19 columns]

# %% [markdown]
# ### create an excel to store an entity

# %%
# data['tindak_pidana'] = ''
# data['pelanggaran_kuhp'] = ''
# data['putusan_hukuman'] = ''
# data['tuntutan_hukuman'] = ''
# data[['nama_file', 'penuntut_umum', 'terdakwa', 'nomor', 'tanggal_musyawarah', 'hakim_ketua',
#        'hakim_anggota', 'panitera', 'tindak_pidana', 'tuntutan_hukuman', 'pelanggaran_kuhp',
#        'putusan_hukuman']].to_excel("entity_data_all.xlsx", index=False)

# %%
entities = pd.read_excel(f"{PATH}/entity_data_all.xlsx")
entities
# Out:
#                    nama_file                    penuntut_umum  \
# 0       48_Pid.B_2024_PN_Bkl            DEWI IKA AGUSTINA, SH
# 1       42_Pid.B_2024_PN_Bkl  NANDINI PARAHITA YULISANI, S.H.
# 2       49_Pid.B_2024_PN_Bkl               UMU LATHIEFAH, S.H
# 3       56_Pid.B_2024_PN_Bkl             FAJRINI FAISAH, S.H.
# 4       57_Pid.B_2024_PN_Bkl             FAJRINI FAISAH, S.H.
# ..                       ...                              ...
# 744  274_Pid.Sus_2021_PN_Smp                NUR FAJJRIYAH, SH
# 745    272_Pid.B_2021_PN_Smp         HARRY ACHMAD DWI MARYONO
# 746  220_Pid.Sus_2021_PN_Smp                NUR FAJJRIYAH, SH
# 747    293_Pid.B_2021_PN_Smp             R. TEDDY ROOMIUS, SH
# 748    254_Pid.B_2021_PN_Smp          SURYA RIZAL HERTADY, SH
#
#                                     terdakwa                    nomor  \
# 3                                            penadahan
# 4                  pencurian dalam keadaan memberatkan
# ..                                                 ...
# 744  dengan sengaja membujuk anak melakukan Persetu...
# 745                                       Penganiayaan
# 746  Dengan sengaja melakukan tipu muslihat memaksa...
# 747                                          Perjudian
# 748                                          penadahan
#
#                      tuntutan_hukuman  \
# 0         2 (dua) tahun 2 (dua) bulan
# 1                      6 (enam) bulan
# 2         2 (Dua) Tahun 2 (Dua) Bulan
# 3                      6 (enam) bulan
# 4    2 (dua) tahun dan 5 (lima) bulan
# ..                                ...
# 744                   7 (Tujuh) Tahun
# 745                  5 ( LIMA ) Bulan
# 746              9 ( sembilan ) Tahun
# 747                  4 (empat ) bulan
# 748                         7 (Tujuh)
#
#                                       pelanggaran_kuhp  \
# 0                              Pasal 363 ayat (2) KUHP
# 1    Pasal 335 ayat (1) Kitab Undang-Undang Hukum P...
# 2                              Pasal 363 ayat (2) KUHP
# 3      Pasal 480 ke-1 Kitab Undang-Undang Hukum Pidana
# 4                Pasal 363 ayat (1) ke-3 dan ke-4 KUHP
# ..                                                 ...
# 744  Pasal 81 ayat (2) Undang - Undang Republik Ind...
# 745  Pasal 351 ayat (1) Kitab Undang -Undang Hukum ...
# 746  Pasal 82 ayat (2) U ndang - Undang Republik In...
# 747                       Pasal 303 Ayat (l) ke.2 KUHP
# 748                           Pasal 480 ayat (1 ) KUHP
#
#                            putusan_hukuman
# 0    1 (satu) Tahun dan 10 (sepuluh) bulan
# 1                           5 (lima) bulan
# 2    1 (satu) Tahun dan 10 (sepuluh) bulan
# 3     4 (empat) Bulan 15 (lima belas) Hari
# 4                            2 (dua) tahum
# ..                                     ...
# 744                       5 (lima ) Tahun,
# 745       3 (tiga) bulan dan 5 (lima) hari
# 746                         6 (enam) tahun
# 747                         3 (tiga) bulan
# 748                         5 (lima) bulan
#
# [749 rows x 12 columns]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# # Preprocessing

# %%
from tqdm import tqdm
import pandas as pd
import gdown
import re

# %% [markdown]
# load dataset

# %%
PATH = '/content/drive/MyDrive/Skripsi/Code/Data'

# %%
data = pd.read_csv(f"{PATH}/data_all.csv")
data = data[['nama_file', 'content']]
data
# Out:
#                        nama_file  \
# 0       48_Pid.B_2024_PN_Bkl.pdf
# 1       42_Pid.B_2024_PN_Bkl.pdf
# 2       49_Pid.B_2024_PN_Bkl.pdf
# 3       56_Pid.B_2024_PN_Bkl.pdf
# 4       57_Pid.B_2024_PN_Bkl.pdf
# ..                           ...
# 744  274_Pid.Sus_2021_PN_Smp.pdf
# 745    272_Pid.B_2021_PN_Smp.pdf
# 746  220_Pid.Sus_2021_PN_Smp.pdf
# 747    293_Pid.B_2021_PN_Smp.pdf
# 748    254_Pid.B_2021_PN_Smp.pdf
#
#                                                content
# 0    PUTUSAN\nNomor 48/Pid.B/2024/PN Bkl\nDEMI KEAD...
# 1    PUTUSAN\nNomor 42/Pid.B/2024/PN Bkl\nDEMI KEAD...
# 2    PUTUSAN\nNomor 49/Pid.B/2024/PN Bkl\nDEMI KEAD...
# 748                   Panitera Pengganti Suraji
#
#                                          tindak_pidana  \
# 0                  Pencurian Dalam Keadaan Memberatkan
# 1    Secara Melawan Hukum Memaksa Orang Lain Supaya...
# 2                  Pencurian Dalam Keadaan Memberatkan
# 3                                            penadahan
# 4                  pencurian dalam keadaan memberatkan
# ..                                                 ...
# 744  dengan sengaja membujuk anak melakukan Persetu...
# 745                                       Penganiayaan
# 746  Dengan sengaja melakukan tipu muslihat memaksa...
# 747                                          Perjudian
# 748                                          penadahan
#
#                      tuntutan_hukuman  \
# 0         2 (dua) tahun 2 (dua) bulan
# 1                      6 (enam) bulan
# 2         2 (Dua) Tahun 2 (Dua) Bulan
# 3                      6 (enam) bulan
# 4    2 (dua) tahun dan 5 (lima) bulan
# ..                                ...
# 744                   7 (Tujuh) Tahun
# 745                    5 (lima) Bulan
# 746                9 (sembilan) Tahun
# 747                   4 (empat) bulan
# 748                         7 (Tujuh)
#
#                                       pelanggaran_kuhp  \
# 0                              Pasal 363 ayat (2) KUHP
# 1    Pasal 335 ayat (1) Kitab Undang-Undang Hukum P...
# 2                              Pasal 363 ayat (2) KUHP
# 3      Pasal 480 ke-1 Kitab Undang-Undang Hukum Pidana
# 4                Pasal 363 ayat (1) ke-3 dan ke-4 KUHP
# ..                                                 ...
# 744  Pasal 81 ayat (2) Undang - Undang Republik Ind...
# 745  Pasal 351 ayat (1) Kitab Undang -Undang Hukum ...
# 746  Pasal 82 ayat (2) U ndang - Undang Republik In...
# 747                       Pasal 303 Ayat (l) ke.2 KUHP
# 748                            Pasal 480 ayat (1) KUHP
#
#                            putusan_hukuman
# 0    1 (satu) Tahun dan 10 (sepuluh) bulan
# 1                           5 (lima) bulan
# 2    1 (satu) Tahun dan 10 (sepuluh) bulan
# 3     4 (empat) Bulan 15 (lima belas) Hari
# 4                            2 (dua) tahum
# ..                                     ...
# 744                        5 (LIMA) Tahun,
# 745       3 (tiga) bulan dan 5 (lima) hari
# 746                         6 (enam) tahun
# 747                         3 (tiga) bulan
# 748                         5 (lima) bulan
#
# [749 rows x 12 columns]

# %%
entities.columns
# Out:
# Index(['nama_file', 'penuntut_umum', 'terdakwa', 'nomor', 'tanggal_musyawarah',
#        'hakim_ketua', 'hakim_anggota', 'panitera', 'tindak_pidana',
#        'tuntutan_hukuman', 'pelanggaran_kuhp', 'putusan_hukuman'],
#       dtype='object')

# %%
missing_values = entities.isnull().sum()
missing_values
# Out:
# nama_file               0
# penuntut_umum         123
# terdakwa                1
# nomor                   0
# tanggal_musyawarah      0
# hakim_ketua             0
# hakim_anggota           0
# panitera                0
# tindak_pidana           6
# tuntutan_hukuman       13
# pelanggaran_kuhp        9
# putusan_hukuman        17
# dtype: int64

# %% [markdown]
# hapus data yang terdapat missing value

# %%
entities = entities.dropna()
entities = entities.applymap(str)
entities
# Out:
#                    nama_file                    penuntut_umum  \
# 0       48_Pid.B_2024_PN_Bkl            DEWI IKA AGUSTINA, SH
# 1       42_Pid.B_2024_PN_Bkl  NANDINI PARAHITA YULISANI, S.H.
# 745    272_Pid.B_2021_PN_Smp.pdf
# 746  220_Pid.Sus_2021_PN_Smp.pdf
# 747    293_Pid.B_2021_PN_Smp.pdf
# 748    254_Pid.B_2021_PN_Smp.pdf
#
#                                                content
# 0    PUTUSAN\nNomor 48/Pid.B/2024/PN Bkl\nDEMI KEAD...
# 1    PUTUSAN\nNomor 42/Pid.B/2024/PN Bkl\nDEMI KEAD...
# 2    PUTUSAN\nNomor 49/Pid.B/2024/PN Bkl\nDEMI KEAD...
# 3    PUTUSAN\nNomor 56/Pid.B/2024/PN Bkl\nDEMI KEAD...
# 4    PUTUSAN\nNomor 57/Pid.B/2024/PN Bkl\nDEMI KEAD...
# ..                                                 ...
# 744  PUTUSAN \nNomor 274/Pid.Sus/2021/PN Smp \n \nD...
# 745  PUTUSAN \nNomor 272/Pid.B/2021/PN Smp \n \nDEM...
# 746  PUTUSAN \nNomor 220/Pid.Sus/2021/PN Smp \n \nD...
# 747  PUTUSAN \nNomor 293/Pid.B/2021/PN Smp \n \nDEM...
# 748  PUTUSAN \nNomor 254/Pid.B/2021 /PN Smp \n \nDE...
#
# [602 rows x 2 columns]

# %% [markdown]
# ## formatting data

# %%
def format_penuntut_umum(penuntut_umum):
    penuntut_umum = re.sub(r'\b(S\.H\.?|M\.H\.?|SH|MH)\b', '', penuntut_umum).replace(',', '')
    if any(char.isdigit() for char in penuntut_umum):
        penuntut_umum = re.findall(r'\d+\.(.*?)\s*(?=\d+\.|$)', penuntut_umum.lower())
    else:
        penuntut_umum = [penuntut_umum.lower().strip()]

    penuntut_umum = [name.rstrip('.') for name in penuntut_umum]
    penuntut_umum = [re.sub(r'\s*\.\s*$', '', name).strip() for name in penuntut_umum]
    return penuntut_umum

def format_terdakwa(terdakwa):
    if any(char.isdigit() for char in terdakwa):
        terdakwa = re.findall(r'\d+\.(.*?)\s*(?=\d+\.|$)', terdakwa.lower())
    else:
        terdakwa = [terdakwa.lower().strip()]
    return terdakwa

def format_tuntutan(tuntutan):
    tuntutan_list = tuntutan.lower().split(';')
    tuntutan_list = [tuntutan.strip() for tuntutan in tuntutan_list]
    return tuntutan_list

def format_putusan(putusan):
    putusan_list = putusan.lower().split(';')
    putusan_list = [putusan.strip() for putusan in putusan_list]
    return putusan_list

entities.fillna('', inplace=True)
entities["penuntut_umum"] = entities["penuntut_umum"].apply(lambda x: format_penuntut_umum(x))
entities["terdakwa"] = entities["terdakwa"].apply(lambda x: format_terdakwa(x))
entities["nomor"] = entities["nomor"].apply(lambda x: x.lower().strip())
entities["tanggal_musyawarah"] = entities["tanggal_musyawarah"].apply(lambda x: re.sub(r'\b0+(\d+)', r'\1', x.lower().replace('nopember', 'november').strip()))
entities["hakim_ketua"] = entities["hakim_ketua"].apply(lambda x: x.lower().replace("hakim ketua", '').replace("hakim tunggal", '').strip())
entities["hakim_anggota"] = entities["hakim_anggota"].apply(lambda x: re.sub(r'\bbr\b', '', x.lower().replace("hakim anggota", '').replace("hakim tunggal", '')).strip().split(','))
entities["panitera"] = entities["panitera"].apply(lambda x: x.lower().replace("panitera pengganti", "").replace(":", "").strip())
entities["tindak_pidana"] = entities["tindak_pidana"].apply(lambda x: str(x).lower().strip() if isinstance(x, str) else x)
entities["tuntutan_hukuman"] = entities["tuntutan_hukuman"].apply(lambda x: format_tuntutan(str(x)) if isinstance(x, str) else x)
entities["pelanggaran_kuhp"] = entities["pelanggaran_kuhp"].apply(lambda x: str(x).lower().strip() if isinstance(x, str) else x)
entities["putusan_hukuman"] = entities["putusan_hukuman"].apply(lambda x: format_putusan(str(x)) if isinstance(x, str) else x)
entities
# Out:
#                    nama_file                penuntut_umum  \
# 0       48_Pid.B_2024_PN_Bkl          [dewi ika agustina]
# 1       42_Pid.B_2024_PN_Bkl  [nandini parahita yulisani]
# 2       49_Pid.B_2024_PN_Bkl              [umu lathiefah]
# 3       56_Pid.B_2024_PN_Bkl             [fajrini faisah]
# 4       57_Pid.B_2024_PN_Bkl             [fajrini faisah]
# ..                       ...                          ...
# 744  274_Pid.Sus_2021_PN_Smp             [nur fajjriy ah]
# 745    272_Pid.B_2021_PN_Smp   [harry achmad dwi maryono]
# 746  220_Pid.Sus_2021_PN_Smp              [nur fajjriyah]
# 747    293_Pid.B_2021_PN_Smp             [r.tedy roomius]
# 748    254_Pid.B_2021_PN_Smp                [surya rizal]
#
#                                    terdakwa                    nomor  \
# 0                      [tislan bin mukamar]     48/pid.b/2024/pn bkl
# 1                        [beiri bin bunali]     42/pid.b/2024/pn bkl
# 2                      [fandi bin sulaiman]     49/pid.b/2024/pn bkl
# 3                         [pandi bin sidik]     56/pid.b/2024/pn bkl
# 4    [mustofa al. jarwot bin hadenan (alm)]     57/pid.b/2024/pn bkl
# ..                                      ...                      ...
# 744              [zaiful islam bin mudirun]  274/pid.sus/2021/pn smp
# 745             [abdul mughnis bin jauhari]    272/pid.b/2021/pn smp
# 746                   [sukrawi bin supatmo]  220/pid.sus/2021/pn smp
# 747  [asnawi bin syafi i, hormah bin samli]    293/pid.b/2021/pn smp
# 748                  [lutpi bin moh. dulla]    254/pid.b/2021/pn smp
#
#     tanggal_musyawarah             hakim_ketua  \
# 0           2 mei 2024  ernila widikartikawati
# 1           2 mei 2024            zainal ahmad
# 2           2 mei 2024  ernila widikartikawati
# 3           2 mei 2024            zainal ahmad
# 4           2 mei 2024  ernila widikartikawati
# ..                 ...                     ...
# 744    20 januari 2022           yahya wahyudi
# 745    13 januari 2022           yahya wahyudi
# 746     4 januari 2022    yuniar yudha himawan
# 747     4 januari 2022    yuniar yudha himawan
# 748   27 desember 2021  arie andhika adikresna
#
#                                          hakim_anggota  \
# 0             [wahyu eko suryowati,    satrio budiono]
# 1      [wienda kresnantyo,    kadek dwi krisna ananda]
# 2             [wahyu eko suryowati,    satrio budiono]
# 3      [wienda kresnantyo,    kadek dwi krisna ananda]
# 4             [wahyu eko suryowati,    satrio budiono]
# ..                                                 ...
# 744          [anjar kumboro,    muhammad arief fatony]
# 745         [muhammad arief fatony,     anjar kumboro]
# 746                 [yahya wahyudi,     anjar kumboro]
# 747                 [yahya wahyudi,     anjar kumboro]
# 748  [muhammad arief fatony,     iksandiaji yuris f...
#
#                    panitera  \
# 0              hosnol bakri
# 1    rr. koosbandriyah a .s
# 2              hosnol bakri
# 3                  naruddin
# 4         h. mohammad asari
# ..                      ...
# 744       edi haris mulyono
# 745                sugiarto
# 746                sugiarto
# 747        nani irianingsih
# 748                  suraji
#
#                                          tindak_pidana  \
# 0                  pencurian dalam keadaan memberatkan
# 1    secara melawan hukum memaksa orang lain supaya...
# 2                  pencurian dalam keadaan memberatkan
# 3                                            penadahan
# 4                  pencurian dalam keadaan memberatkan
# ..                                                 ...
# 744  dengan sengaja membujuk anak melakukan persetu...
# 745                                       penganiayaan
# 746  dengan sengaja melakukan tipu muslihat memaksa...
# 747                                          perjudian
# 748                                          penadahan
#
#                        tuntutan_hukuman  \
# 0         [2 (dua) tahun 2 (dua) bulan]
# 1                      [6 (enam) bulan]
# 2         [2 (dua) tahun 2 (dua) bulan]
# 3                      [6 (enam) bulan]
# 4    [2 (dua) tahun dan 5 (lima) bulan]
# ..                                  ...
# 744                   [7 (tujuh) tahun]
# 745                    [5 (lima) bulan]
# 746                [9 (sembilan) tahun]
# 747                   [4 (empat) bulan]
# 748                         [7 (tujuh)]
#
#                                       pelanggaran_kuhp  \
# 0                              pasal 363 ayat (2) kuhp
# 1    pasal 335 ayat (1) kitab undang-undang hukum p...
# 2                              pasal 363 ayat (2) kuhp
# 3      pasal 480 ke-1 kitab undang-undang hukum pidana
# 4                pasal 363 ayat (1) ke-3 dan ke-4 kuhp
# ..                                                 ...
# 744  pasal 81 ayat (2) undang - undang republik ind...
# 745  pasal 351 ayat (1) kitab undang -undang hukum ...
# 746  pasal 82 ayat (2) u ndang - undang republik in...
# 747                       pasal 303 ayat (l) ke.2 kuhp
# 748                            pasal 480 ayat (1) kuhp
#
#                              putusan_hukuman
# 0    [1 (satu) tahun dan 10 (sepuluh) bulan]
# 1                           [5 (lima) bulan]
# 2    [1 (satu) tahun dan 10 (sepuluh) bulan]
# 3     [4 (empat) bulan 15 (lima belas) hari]
# 4                            [2 (dua) tahum]
# ..                                       ...
# 744                        [5 (lima) tahun,]
# 745       [3 (tiga) bulan dan 5 (lima) hari]
# 746                         [6 (enam) tahun]
# 747                         [3 (tiga) bulan]
# 748                         [5 (lima) bulan]
#
# [602 rows x 12 columns]

# %% [markdown]
# ## cleaning text v1

# %%
def clean_text(text):
    text = text.replace('P U T U S A N', 'PUTUSAN').replace('T erdakwa', 'Terdakwa').replace('T empat', 'Tempat').replace('T ahun', 'Tahun')
    text = text.replace('P  E  N  E  T  A  P  A  N', 'PENETAPAN').replace('J u m l a h', 'Jumlah').replace('M E N G A D I L I', 'MENGADILI')
    text = re.sub(r'Halaman \d+', ' ', text)
    text = re.sub(r'\b0+(\d+)', r'\1', text)
    text = text.replace('\uf0d8', '').replace('\uf0b7', '').replace('\n', ' ')
    text = re.sub(r'([“”"])', r' \1 ', text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

data['content'] = data["content"].apply(clean_text)

# %% [markdown]
# ## clean text v2

# %%
# def clean_text(text):
#     # Ganti kata yang dipisahkan dengan spasi menjadi bentuk yang benar
#     text = text.replace('P U T U S A N', 'PUTUSAN').replace('T erdakwa', 'Terdakwa').replace('T empat', 'Tempat').replace('T ahun', 'Tahun')
#     text = text.replace('P  E  N  E  T  A  P  A  N', 'PENETAPAN').replace('J u m l a h', 'Jumlah').replace('M E N G A D I L I', 'MENGADILI')
#     # Hapus pola tertentu seperti "Hal.", "Halaman", dan "Putusan Nomor"
#     text = re.sub(r'(Hal\.\s*\S+(?:\s*\S+)?\.?\s*)|(Halaman \d+(?:\.\d+)?\s*)|Putusan Nomor \S+\s*', '', text)
#     # Hapus karakter Unicode yang tidak diinginkan dan ganti newline dengan spasi
#     text = text.replace('\uf0d8', '').replace('\uf0b7', '').replace('\n', ' ')
#     # Tambahkan spasi di sekitar tanda kutip
#     text = re.sub(r'([“”"])', r' \1 ', text)
#     # Ganti beberapa spasi dengan satu spasi
#     text = re.sub(r'\s+', ' ', text)
#     # Hapus pola "halaman x dari y"
#     text = re.sub(r'halaman\s*\d+\s*dari\s*\d+\s*', '', text)
#     # Hapus pola "dari x bkl" dan "dari x smp" di awal teks, tidak sensitif huruf besar/kecil
#     text = re.sub(r'^\s*dari\s+\d+\s+bkl\s+', '', text, flags=re.IGNORECASE)
#     text = re.sub(r'^\s*dari\s+\d+\s+smp\s+', '', text, flags=re.IGNORECASE)
#     # Perbaiki spasi sebelum pola "/PN"
#     text = re.sub(r'\s+/PN', '/PN', text)
#     # Tambahkan spasi antara "nomor" dan angka berikutnya
#     text = re.sub(r'(?i)(nomor)(\d+)', r'\1 \2', text)
#     # Hapus spasi di dalam tanda kurung
#     text = re.sub(r'\(\s*(.*?)\s*\)', r'(\1)', text)
#     # Tambahkan spasi setelah tanda titik dua jika tidak ada
#     text = re.sub(r':\s*(\S)', r': \1', text)
#     # Tambahkan spasi sebelum "SH" dan "S" setelah koma, tidak sensitif huruf besar/kecil
#     text = re.sub(r',\s*(sh)', r' ,\1', text, flags=re.IGNORECASE)
#     text = re.sub(r',\s*(s)', r' ,\1', text, flags=re.IGNORECASE)
#     # Hapus spasi antara angka dan teks di dalam tanda kurung
#     text = re.sub(r'(\d)\s*\((.*?)\)', r'\1 (\2)', text)
#     # Perbaiki spasi sebelum pola "/pid"
#     text = re.sub(r'(\d+)\s*/pid', r'\1/pid', text)
#     # Standarisasi format untuk nomor kasus
#     text = re.sub(r'(\d+)\s*/\s*(pid\.\w+)\s*/\s*(\d{4})\s*/\s*(pn)', r'\1/\2/\3/\4', text, flags=re.IGNORECASE)

#     return text.strip()

# def multiple_replace(text, replacements):
#     regex = re.compile('|'.join(re.escape(key) for key in replacements.keys()))

#     def replace(match):
#         return replacements[match.group(0)]

#     return regex.sub(replace, text)

# replacements = {
#     '1 0 (sepuluh)': '10 (sepuluh)', 'Nopember': 'November','Pebruari': 'Februari', 'Halaman1dari13Putusan' : 'Putusan', ':ABDUL' : 'ABDUL', 'A STUTI' :'ASTUTI', "SA'AT" : 'SA’AT', "Rifa'i" : 'Rifa’i',
#     'N omor': 'Nomor', 'K itab': 'Kitab', 'Hakmelakukan': 'Hak melakukan', '20 20': '2020', 'ke manfatan': 'kemanfatan', '2 7' : '27', 'A gustus' : 'Agustus', 'September2023,' : 'September 2023,',
#     '( 2)': '(2)', '.,': ' .,', ',S': ' ,S', 'PN.Pmk': 'PN Pmk', 'Pencuriandalam': 'Pencurian dalam', 'B in' : 'bin', 'Aapril' : 'April', 'Ja nuari' : 'Januari', 'Ted dy' : 'Teddy', 'Ro omius,' : 'Roomius,',
#     'Pembunuhanberencana': 'Pembunuhan berencana', 'h ukum': 'hukum', 'PNPmk': 'PN Pmk', '//PN': '/PN','R .B.': 'R. B.', '2022oleh' : '2022', 'olehFajrini' : 'oleh Fajrini', 'Alimuddi n,' : 'Alimuddin,',
#     '202 3/PN': '2023/PN', 'Perkos aan': 'Perkosaan', 'memberatka n': 'memberatkan', 'p idana': 'pidana', 'sebag aimana': 'sebagaimana', '1 0' : '10','bulan;' : 'bulan', '2 23' : '2023',
#     'Ram dhani': 'Ramdhani', 'H ADY': 'HADY', '2 023': '2023','2 022': '2022', 'f isik': 'fisik', 'be rsalah': 'bersalah', '(sepuluh )': '(sepuluh)', 'M U A R I' : 'MUARI', 'Bulan;' : 'Bulan', 'Ap ril' : 'April',
#     '(enam )': '(enam)', 'No mor': 'Nomor', '( 3)': '(3)', 'Nomo r': 'Nomor', 'an ak': 'anak', 'tuj uh': 'tujuh', 'hu bungan': 'hubungan', 'KADIR;' : 'KADIR', 'selam a1 (satu)' : 'selama 1 (satu)',
#     '(empat )' : '(empat)', "PA'I" : 'PA’I', 'S eptember' : 'September',
#     'Keadaa n' : 'Keadaan', '27Januari' : '27 Januari', 'Nomor265/Pid.B/2021/PN' : 'Nomor 265/Pid.B/2021/PN', 'Bulan;3.Menetapkan' : 'Bulan 3.Menetapkan','bulan;3.Menetapkan' : 'bulan 3.Menetapkan', 'Januari,2023' : 'Januari 2023',
#     '202 2' : '2022','202 4' : '2024', '202 3' : '2023','2023//' : '2023', '20 22' : '2022','20 21' : '2021','202 1' : '2021', '27januari' : '27 januari', 'januari,2023' : 'januari 2023', 'sepember' : 'september',
#     'Bk l' : 'Bkl', 'bk l' : 'bkl','pm k' : 'pmk', 'bki' : 'bkl',  'pid.b /' : 'pid.b/', 'pn.' : 'pn ', 'pid. b' : 'pid.b', 'pnpmk' : 'pn pmk', '2023pn' : '2023 pn', 'smp.' : 'smp',
#     '(al m)' : '(alm)', 'Al m' : 'Alm', "'" : '’', 'b in' : 'bin', 'bu lan' : 'bulan', 'kuhpdan' : 'kuhp dan',
#     'pencuriandalam' : 'pencurian dalam', 'keadaa n' : 'keadaan', 'pembunuhanberencana' : 'pembunuhan berencana', 'bulan3.menetapkan' : 'bulan 3.menetapkan', 'bulan3.menyatakan' :  'bulan 3.menyatakan',
#     't aufik' : 'taufik', 'olehhaidir' : 'oleh haidir','olehfajrini' : 'oleh fajrini', 'janurai' : 'januari', 'nopember': 'november','pebruari': 'februari','a gustus' : 'agustus', 'september2023,' : 'september 2023,','aapril' : 'april', 'ja nuari' : 'januari',
#     'no mor': 'nomor', ',serta' : ', serta', 'agussyamsul' : 'agus syamsul', 'a stuti' : 'astuti'
# }

# data['content'] = data["content"].apply(clean_text).apply(lambda x: multiple_replace(x, replacements))
# data
# Out:
#                        nama_file  \
# 0       48_Pid.B_2024_PN_Bkl.pdf
# 1       42_Pid.B_2024_PN_Bkl.pdf
# 2       49_Pid.B_2024_PN_Bkl.pdf
# 3       56_Pid.B_2024_PN_Bkl.pdf
# 4       57_Pid.B_2024_PN_Bkl.pdf
# ..                           ...
# 744  274_Pid.Sus_2021_PN_Smp.pdf
# 745    272_Pid.B_2021_PN_Smp.pdf
# 746  220_Pid.Sus_2021_PN_Smp.pdf
# 747    293_Pid.B_2021_PN_Smp.pdf
# 748    254_Pid.B_2021_PN_Smp.pdf
#
#                                                content
# 0    PUTUSAN Nomor 48/Pid.B/2024/PN Bkl DEMI KEADIL...
# 1    PUTUSAN Nomor 42/Pid.B/2024/PN Bkl DEMI KEADIL...
# 2    PUTUSAN Nomor 49/Pid.B/2024/PN Bkl DEMI KEADIL...
# 3    PUTUSAN Nomor 56/Pid.B/2024/PN Bkl DEMI KEADIL...
# 4    PUTUSAN Nomor 57/Pid.B/2024/PN Bkl DEMI KEADIL...
# ..                                                 ...
# 744  PUTUSAN Nomor 274/Pid.Sus/2021/PN Smp DEMI KEA...
# 745  PUTUSAN Nomor 272/Pid.B/2021/PN Smp DEMI KEADI...
# 746  PUTUSAN Nomor 220/Pid.Sus/2021/PN Smp DEMI KEA...
# 747  PUTUSAN Nomor 293/Pid.B/2021/PN Smp DEMI KEADI...
# 748  PUTUSAN Nomor 254/Pid.B/2021/PN Smp DEMI KEADI...
#
# [602 rows x 2 columns]

# %% [markdown]
# ## anotation

# %%
data_concat = pd.concat([entities, data['content']], axis=1)
data_concat.reset_index(drop=True, inplace=True)
data_concat
# Out:
#                    nama_file                penuntut_umum  \
# 0       48_Pid.B_2024_PN_Bkl          [dewi ika agustina]
# 1       42_Pid.B_2024_PN_Bkl  [nandini parahita yulisani]
# 2       49_Pid.B_2024_PN_Bkl              [umu lathiefah]
# 3       56_Pid.B_2024_PN_Bkl             [fajrini faisah]
# 4       57_Pid.B_2024_PN_Bkl             [fajrini faisah]
# ..                       ...                          ...
# 597  274_Pid.Sus_2021_PN_Smp             [nur fajjriy ah]
# 598    272_Pid.B_2021_PN_Smp   [harry achmad dwi maryono]
# 599  220_Pid.Sus_2021_PN_Smp              [nur fajjriyah]
# 600    293_Pid.B_2021_PN_Smp             [r.tedy roomius]
# 601    254_Pid.B_2021_PN_Smp                [surya rizal]
#
#                                    terdakwa                    nomor  \
# 0                      [tislan bin mukamar]     48/pid.b/2024/pn bkl
# 1                        [beiri bin bunali]     42/pid.b/2024/pn bkl
# 2                      [fandi bin sulaiman]     49/pid.b/2024/pn bkl
# 3                         [pandi bin sidik]     56/pid.b/2024/pn bkl
# 4    [mustofa al. jarwot bin hadenan (alm)]     57/pid.b/2024/pn bkl
# ..                                      ...                      ...
# 597              [zaiful islam bin mudirun]  274/pid.sus/2021/pn smp
# 598             [abdul mughnis bin jauhari]    272/pid.b/2021/pn smp
# 599                   [sukrawi bin supatmo]  220/pid.sus/2021/pn smp
# 600  [asnawi bin syafi i, hormah bin samli]    293/pid.b/2021/pn smp
# 601                  [lutpi bin moh. dulla]    254/pid.b/2021/pn smp
#
#     tanggal_musyawarah             hakim_ketua  \
# 0           2 mei 2024  ernila widikartikawati
# 1           2 mei 2024            zainal ahmad
# 2           2 mei 2024  ernila widikartikawati
# 3           2 mei 2024            zainal ahmad
# 4           2 mei 2024  ernila widikartikawati
# ..                 ...                     ...
# 597    20 januari 2022           yahya wahyudi
# 598    13 januari 2022           yahya wahyudi
# 599     4 januari 2022    yuniar yudha himawan
# 600     4 januari 2022    yuniar yudha himawan
# 601   27 desember 2021  arie andhika adikresna
#
#                                          hakim_anggota  \
# 0             [wahyu eko suryowati,    satrio budiono]
# 1      [wienda kresnantyo,    kadek dwi krisna ananda]
# 2             [wahyu eko suryowati,    satrio budiono]
# 3      [wienda kresnantyo,    kadek dwi krisna ananda]
# 4             [wahyu eko suryowati,    satrio budiono]
# ..                                                 ...
# 597          [anjar kumboro,    muhammad arief fatony]
# 598         [muhammad arief fatony,     anjar kumboro]
# 599                 [yahya wahyudi,     anjar kumboro]
# 600                 [yahya wahyudi,     anjar kumboro]
# 601  [muhammad arief fatony,     iksandiaji yuris f...
#
#                    panitera  \
# 0              hosnol bakri
# 1    rr. koosbandriyah a .s
# 2              hosnol bakri
# 3                  naruddin
# 4         h. mohammad asari
# ..                      ...
# 597       edi haris mulyono
# 598                sugiarto
# 599                sugiarto
# 600        nani irianingsih
# 601                  suraji
#
#                                          tindak_pidana  \
# 0                  pencurian dalam keadaan memberatkan
# 1    secara melawan hukum memaksa orang lain supaya...
# 2                  pencurian dalam keadaan memberatkan
# 3                                            penadahan
# 4                  pencurian dalam keadaan memberatkan
# ..                                                 ...
# 597  dengan sengaja membujuk anak melakukan persetu...
# 598                                       penganiayaan
# 599  dengan sengaja melakukan tipu muslihat memaksa...
# 600                                          perjudian
# 601                                          penadahan
#
#                        tuntutan_hukuman  \
# 0         [2 (dua) tahun 2 (dua) bulan]
# 1                      [6 (enam) bulan]
# 2         [2 (dua) tahun 2 (dua) bulan]
# 3                      [6 (enam) bulan]
# 4    [2 (dua) tahun dan 5 (lima) bulan]
# ..                                  ...
# 597                   [7 (tujuh) tahun]
# 598                    [5 (lima) bulan]
# 599                [9 (sembilan) tahun]
# 600                   [4 (empat) bulan]
# 601                         [7 (tujuh)]
#
#                                       pelanggaran_kuhp  \
# 0                              pasal 363 ayat (2) kuhp
# 1    pasal 335 ayat (1) kitab undang-undang hukum p...
# 2                              pasal 363 ayat (2) kuhp
# 3      pasal 480 ke-1 kitab undang-undang hukum pidana
# 4                pasal 363 ayat (1) ke-3 dan ke-4 kuhp
# ..                                                 ...
# 597  pasal 81 ayat (2) undang - undang republik ind...
# 598  pasal 351 ayat (1) kitab undang -undang hukum ...
# 599  pasal 82 ayat (2) u ndang - undang republik in...
# 600                       pasal 303 ayat (l) ke.2 kuhp
# 601                            pasal 480 ayat (1) kuhp
#
#                              putusan_hukuman  \
# 0    [1 (satu) tahun dan 10 (sepuluh) bulan]
# 1                           [5 (lima) bulan]
# 2    [1 (satu) tahun dan 10 (sepuluh) bulan]
# 3     [4 (empat) bulan 15 (lima belas) hari]
# 4                            [2 (dua) tahum]
# ..                                       ...
# 597                        [5 (lima) tahun,]
# 598       [3 (tiga) bulan dan 5 (lima) hari]
# 599                         [6 (enam) tahun]
# 600                         [3 (tiga) bulan]
# 601                         [5 (lima) bulan]
#
#                                                content
# 0    PUTUSAN Nomor 48/Pid.B/2024/PN Bkl DEMI KEADIL...
# 1    PUTUSAN Nomor 42/Pid.B/2024/PN Bkl DEMI KEADIL...
# 2    PUTUSAN Nomor 49/Pid.B/2024/PN Bkl DEMI KEADIL...
# 3    PUTUSAN Nomor 56/Pid.B/2024/PN Bkl DEMI KEADIL...
# 4    PUTUSAN Nomor 57/Pid.B/2024/PN Bkl DEMI KEADIL...
# ..                                                 ...
# 597  PUTUSAN Nomor 274/Pid.Sus/2021/PN Smp DEMI KEA...
# 598  PUTUSAN Nomor 272/Pid.B/2021/PN Smp DEMI KEADI...
# 599  PUTUSAN Nomor 220/Pid.Sus/2021/PN Smp DEMI KEA...
# 600  PUTUSAN Nomor 293/Pid.B/2021/PN Smp DEMI KEADI...
# 601  PUTUSAN Nomor 254/Pid.B/2021/PN Smp DEMI KEADI...
#
# [602 rows x 13 columns]

# %% [markdown]
# ### create label dictionary

# %%
def generate_label(entities):
  label = {}

  def update_label(entity_list, label, label_value):
    if entity_list:  # Periksa apakah entity_list tidak kosong
        if len(entity_list) > 1:
            label.update({ent.strip(): label_value for ent in entity_list})
        else:
            if (entity_list[0]) == '':
              pass
            else:
              label[entity_list[0].strip()] = label_value

  # Periksa dan perbarui kamus label untuk setiap entitas
  if 'penuntut_umum' in entities and entities['penuntut_umum']:
      update_label(entities['penuntut_umum'], label, "B_PROS")

  if 'terdakwa' in entities and entities['terdakwa']:
      update_label(entities['terdakwa'], label, "B_DEFN")

  if 'hakim_anggota' in entities and entities['hakim_anggota']:
      update_label(entities['hakim_anggota'], label, "B_JUDG")

  if 'putusan_hukuman' in entities and entities['putusan_hukuman']:
      update_label(entities['putusan_hukuman'], label, "B_PUNI")

  if 'tuntutan_hukuman' in entities and entities['tuntutan_hukuman']:
      update_label(entities['tuntutan_hukuman'], label, "B_PENA")

  label[entities['nomor']] = "B_VERN"
  label[entities['tanggal_musyawarah']] = "B_TIMV"
  label[entities['hakim_ketua']] = "B_JUDP"
  label[entities['panitera']] = "B_REGI"
  label[entities['tindak_pidana']] = "B_CRIA"
  label[entities['pelanggaran_kuhp']] = "B_ARTV"

  return label

# %% [markdown]
# ### otomatis anotation

# %%
def labeling_token(text, label_dict):
    tokens = text.lower().split()
    labeled_tokens = ['O'] * len(tokens)
    find_label = dict()

    # Buat struktur nested berdasarkan label_dict
    for key, value in label_dict.items():
        if key:  # Pastikan kunci tidak kosong
            words = key.split()
            current_dict = find_label
            for word in words[:-1]:
                word = re.sub(r'[.,;"]', '', word)  # Hapus tanda baca
                current_dict = current_dict.setdefault(word, {})
            if words:
                last_word = re.sub(r'[.,;"]', '', words[-1])
                current_dict[last_word] = {'label': value}

    # List untuk menyimpan indeks token sementara
    temp_idx_token = []
    # Struktur label yang sedang dicari
    find_label_selected = find_label
    # Iterasi melalui token
    for i, token in enumerate(tokens):
        clean_token = re.sub(r'[.,;"]', '', token)  # Hapus tanda baca
        if clean_token in find_label_selected:
            find_label_selected = find_label_selected[clean_token]
            temp_idx_token.append(i)
            if 'label' in find_label_selected:
                # Temukan label untuk token saat ini dan tetapkan ke token
                tag = find_label_selected['label']
                new_label = [tag if ind == 0 else tag.replace('B', 'I') for ind in range(len(temp_idx_token))]
                labeled_tokens[temp_idx_token[0]:temp_idx_token[0] + len(new_label)] = new_label
                temp_idx_token = []
                find_label_selected = find_label
        else:
            temp_idx_token = []
            find_label_selected = find_label

    return labeled_tokens

# %%
def anotasi(data):
    content_results = pd.DataFrame(columns=["doc", "text", "label"])
    count_label = {}
    labels = []

    for doc_idx, (_, row) in tqdm(enumerate(data.iterrows()), total=len(data), desc="Annotating"):
        temp_results = {"doc": [], "text": [], "label": []}

        label = generate_label(row)
        labels.append(label)
        content = row["content"]
        labeled_tokens = labeling_token(content, label)

        doc_str = f"doc:{doc_idx+1}"
        temp_results["doc"].append(doc_str)
        temp_results["text"].append(content.split())
        temp_results["label"].append(labeled_tokens)
        temp_results['label'] = handleDuplicatePena(temp_results['label'])

        temp_data = pd.DataFrame(temp_results)
        count_label.update(countLabel(f"{doc_idx}", temp_data, set(label.values())))
        content_results = pd.concat([content_results, temp_data], ignore_index=True)

    return content_results, count_label, labels

# %%
def handleDuplicatePena(sequences):
    countPena = 0

    for sequence in sequences:
        for i, label in enumerate(sequence):
            if label == 'B_PENA':
                countPena += 1
                if countPena > 1:
                    sequence[i] = 'B_PUNI'
            elif label == 'I_PENA':
                if countPena > 1:
                    sequence[i] = 'I_PUNI'

    return sequences

# %%
def countLabel(doc_idx, data, label_ori):
    result = {}
    label_found = set()
    label_list = set(['B_ARTV', 'B_DEFN', 'B_PROS', 'B_CRIA', 'B_JUDP', 'B_VERN', 'B_PUNI', 'B_JUDG', 'B_REGI', 'B_TIMV', 'B_PENA'])
    for i, row in data.iterrows():
      for t, l in zip(row["text"], row["label"]):
        if l != 'O' and l.replace('I_', 'B_') not in label_found:
          label_found.add(l.replace('I_', 'B_'))

    label_missing = label_list - label_found
    result[f"Dokumen Ke-{doc_idx}"] = (len(label_found), len(label_ori), label_missing)
    return result

def accuracy(result):
  sum_label = 0
  label_in = 0
  for key, value in result.items():
    print(f"{key} => Data Terlebel : {value[0]} ; Total Label : {value[1]} ; Label Hilang : {value[2]}")
    sum_label+= value[1]
    label_in += value[0]

  return f"Accuracy : {label_in/sum_label * 100}"

new_df, count_label, labels = anotasi(data_concat)
new_df
# Out:
# Annotating: 100%|██████████| 602/602 [00:07<00:00, 85.99it/s]
#          doc                                               text  \
# 0      doc:1  [PUTUSAN, Nomor, 48/Pid.B/2024/PN, Bkl, DEMI, ...
# 1      doc:2  [PUTUSAN, Nomor, 42/Pid.B/2024/PN, Bkl, DEMI, ...
# 2      doc:3  [PUTUSAN, Nomor, 49/Pid.B/2024/PN, Bkl, DEMI, ...
# 3      doc:4  [PUTUSAN, Nomor, 56/Pid.B/2024/PN, Bkl, DEMI, ...
# 4      doc:5  [PUTUSAN, Nomor, 57/Pid.B/2024/PN, Bkl, DEMI, ...
# ..       ...                                                ...
# 597  doc:598  [PUTUSAN, Nomor, 274/Pid.Sus/2021/PN, Smp, DEM...
# 598  doc:599  [PUTUSAN, Nomor, 272/Pid.B/2021/PN, Smp, DEMI,...
# 599  doc:600  [PUTUSAN, Nomor, 220/Pid.Sus/2021/PN, Smp, DEM...
# 600  doc:601  [PUTUSAN, Nomor, 293/Pid.B/2021/PN, Smp, DEMI,...
# 601  doc:602  [PUTUSAN, Nomor, 254/Pid.B/2021/PN, Smp, DEMI,...
#
#                                                  label
# 0    [O, O, B_VERN, I_VERN, O, O, O, O, O, O, O, O,...
# 1    [O, O, B_VERN, I_VERN, O, O, O, O, O, O, O, O,...
# 2    [O, O, B_VERN, I_VERN, O, O, O, O, O, O, O, O,...
# 3    [O, O, B_VERN, I_VERN, O, O, O, O, O, O, O, O,...
# 4    [O, O, B_VERN, I_VERN, O, O, O, O, O, O, O, O,...
# ..                                                 ...
# 597  [O, O, B_VERN, I_VERN, O, O, O, O, O, O, O, O,...
# 598  [O, O, B_VERN, I_VERN, O, O, O, O, O, O, O, O,...
# 599  [O, O, B_VERN, I_VERN, O, O, O, O, O, O, O, O,...
# 600  [O, O, B_VERN, I_VERN, O, O, O, O, O, O, O, O,...
# 601  [O, O, B_VERN, I_VERN, O, O, O, O, O, O, O, O,...
#
# [602 rows x 3 columns]

# %%
accuracy(count_label)
# Out:
# Dokumen Ke-0 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-1 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-2 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-3 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-4 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-5 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-6 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-7 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-8 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-9 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-10 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-11 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_REGI'}
# Dokumen Ke-12 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-13 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-14 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-15 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-16 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-17 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-18 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_REGI'}
# Dokumen Ke-19 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-20 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-21 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-22 => Data Terlebel : 10 ; Total Label : 10 ; Label Hilang : {'B_PUNI'}
# Dokumen Ke-23 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-24 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-25 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_TIMV'}
# Dokumen Ke-26 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-27 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-28 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-29 => Data Terlebel : 9 ; Total Label : 11 ; Label Hilang : {'B_REGI', 'B_PENA'}
# Dokumen Ke-30 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-31 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-32 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-33 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-34 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-35 => Data Terlebel : 9 ; Total Label : 11 ; Label Hilang : {'B_PENA', 'B_ARTV'}
# Dokumen Ke-36 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-37 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-38 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-39 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-40 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-41 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-42 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-43 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-44 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-45 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-46 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-47 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-48 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-49 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-50 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-51 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-52 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-53 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-54 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-55 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-56 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-57 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-58 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-59 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-60 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-61 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-62 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-63 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-64 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-65 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-66 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-67 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-68 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-69 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-70 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-71 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-72 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-73 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-74 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-75 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-76 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-77 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-78 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-79 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-80 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-81 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-82 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-83 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-84 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-85 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-86 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-87 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-88 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-89 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-90 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-91 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-92 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-93 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-94 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-95 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-96 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-97 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-98 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-99 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-100 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-101 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-102 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-103 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-104 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-105 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-106 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-107 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-108 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-109 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-110 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-111 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-112 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-113 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-114 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-115 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-116 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-117 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-118 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-119 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-120 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-121 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-122 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-123 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-124 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-125 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-126 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-127 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-128 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-129 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-130 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_VERN'}
# Dokumen Ke-131 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_VERN'}
# Dokumen Ke-132 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-133 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-134 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-135 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-136 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-137 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-138 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-139 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-140 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_VERN'}
# Dokumen Ke-141 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-142 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-143 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-144 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-145 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-146 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-147 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-148 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-149 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-150 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-151 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-152 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-153 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-154 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-155 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-156 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-157 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-158 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-159 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-160 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-161 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-162 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-163 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-164 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-165 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-166 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-167 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-168 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-169 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-170 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-171 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-172 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-173 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-174 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-175 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-176 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-177 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-178 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-179 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_VERN'}
# Dokumen Ke-180 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-181 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-182 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-183 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-184 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-185 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-186 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-187 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-188 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_VERN'}
# Dokumen Ke-189 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-190 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-191 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-192 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-193 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-194 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-195 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-196 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-197 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-198 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-199 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-200 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-201 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-202 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-203 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-204 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-205 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-206 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-207 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-208 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-209 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-210 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-211 => Data Terlebel : 9 ; Total Label : 11 ; Label Hilang : {'B_PENA', 'B_VERN'}
# Dokumen Ke-212 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-213 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-214 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-215 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-216 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-217 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-218 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-219 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-220 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-221 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-222 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-223 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-224 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-225 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-226 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-227 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-228 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-229 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-230 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-231 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-232 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-233 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-234 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-235 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-236 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-237 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-238 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-239 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_VERN'}
# Dokumen Ke-240 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-241 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_VERN'}
# Dokumen Ke-242 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-243 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-244 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-245 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-246 => Data Terlebel : 9 ; Total Label : 11 ; Label Hilang : {'B_PENA', 'B_VERN'}
# Dokumen Ke-247 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-248 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-249 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-250 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-251 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-252 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-253 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-254 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-255 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-256 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-257 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-258 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-259 => Data Terlebel : 9 ; Total Label : 11 ; Label Hilang : {'B_ARTV', 'B_PROS'}
# Dokumen Ke-260 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-261 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-262 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-263 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-264 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-265 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-266 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-267 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-268 => Data Terlebel : 10 ; Total Label : 10 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-269 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-270 => Data Terlebel : 9 ; Total Label : 11 ; Label Hilang : {'B_PENA', 'B_PROS'}
# Dokumen Ke-271 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-272 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-273 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-274 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-275 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-276 => Data Terlebel : 9 ; Total Label : 11 ; Label Hilang : {'B_PENA', 'B_PROS'}
# Dokumen Ke-277 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-278 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-279 => Data Terlebel : 9 ; Total Label : 11 ; Label Hilang : {'B_PENA', 'B_PROS'}
# Dokumen Ke-280 => Data Terlebel : 10 ; Total Label : 10 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-281 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-282 => Data Terlebel : 9 ; Total Label : 11 ; Label Hilang : {'B_PENA', 'B_PROS'}
# Dokumen Ke-283 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-284 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-285 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-286 => Data Terlebel : 9 ; Total Label : 11 ; Label Hilang : {'B_PENA', 'B_PROS'}
# Dokumen Ke-287 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-288 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-289 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-290 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-291 => Data Terlebel : 9 ; Total Label : 11 ; Label Hilang : {'B_PENA', 'B_PROS'}
# Dokumen Ke-292 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-293 => Data Terlebel : 9 ; Total Label : 11 ; Label Hilang : {'B_PUNI', 'B_PROS'}
# Dokumen Ke-294 => Data Terlebel : 9 ; Total Label : 11 ; Label Hilang : {'B_PENA', 'B_PROS'}
# Dokumen Ke-295 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-296 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-297 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-298 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-299 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-300 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-301 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-302 => Data Terlebel : 9 ; Total Label : 11 ; Label Hilang : {'B_PENA', 'B_PROS'}
# Dokumen Ke-303 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-304 => Data Terlebel : 10 ; Total Label : 10 ; Label Hilang : {'B_PUNI'}
# Dokumen Ke-305 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-306 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-307 => Data Terlebel : 9 ; Total Label : 11 ; Label Hilang : {'B_PENA', 'B_PROS'}
# Dokumen Ke-308 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PUNI'}
# Dokumen Ke-309 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-310 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-311 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-312 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-313 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-314 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-315 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-316 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-317 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-318 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-319 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-320 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-321 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-322 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-323 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-324 => Data Terlebel : 9 ; Total Label : 11 ; Label Hilang : {'B_PUNI', 'B_PROS'}
# Dokumen Ke-325 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-326 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-327 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-328 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-329 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-330 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-331 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-332 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-333 => Data Terlebel : 10 ; Total Label : 10 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-334 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-335 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-336 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-337 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-338 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-339 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-340 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-341 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-342 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-343 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-344 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-345 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-346 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-347 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-348 => Data Terlebel : 10 ; Total Label : 10 ; Label Hilang : {'B_DEFN'}
# Dokumen Ke-349 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-350 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-351 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-352 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-353 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-354 => Data Terlebel : 10 ; Total Label : 10 ; Label Hilang : {'B_PUNI'}
# Dokumen Ke-355 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-356 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-357 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-358 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-359 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-360 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-361 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-362 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-363 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-364 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-365 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-366 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-367 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-368 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-369 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-370 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-371 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-372 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-373 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-374 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-375 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-376 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-377 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-378 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-379 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-380 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-381 => Data Terlebel : 10 ; Total Label : 10 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-382 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-383 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-384 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-385 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-386 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-387 => Data Terlebel : 10 ; Total Label : 10 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-388 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-389 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-390 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-391 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-392 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-393 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-394 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-395 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-396 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-397 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-398 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-399 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-400 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-401 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-402 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-403 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-404 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-405 => Data Terlebel : 10 ; Total Label : 10 ; Label Hilang : {'B_PUNI'}
# Dokumen Ke-406 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-407 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-408 => Data Terlebel : 10 ; Total Label : 10 ; Label Hilang : {'B_PUNI'}
# Dokumen Ke-409 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-410 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-411 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-412 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-413 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PUNI'}
# Dokumen Ke-414 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-415 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-416 => Data Terlebel : 9 ; Total Label : 10 ; Label Hilang : {'B_PENA', 'B_PUNI'}
# Dokumen Ke-417 => Data Terlebel : 10 ; Total Label : 10 ; Label Hilang : {'B_PUNI'}
# Dokumen Ke-418 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-419 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-420 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-421 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-422 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-423 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-424 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-425 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PUNI'}
# Dokumen Ke-426 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-427 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-428 => Data Terlebel : 9 ; Total Label : 11 ; Label Hilang : {'B_PENA', 'B_VERN'}
# Dokumen Ke-429 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-430 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PUNI'}
# Dokumen Ke-431 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_VERN'}
# Dokumen Ke-432 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_VERN'}
# Dokumen Ke-433 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-434 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_VERN'}
# Dokumen Ke-435 => Data Terlebel : 9 ; Total Label : 11 ; Label Hilang : {'B_ARTV', 'B_VERN'}
# Dokumen Ke-436 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-437 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-438 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-439 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-440 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-441 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-442 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_VERN'}
# Dokumen Ke-443 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-444 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-445 => Data Terlebel : 9 ; Total Label : 10 ; Label Hilang : {'B_VERN', 'B_PUNI'}
# Dokumen Ke-446 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-447 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-448 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-449 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-450 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-451 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-452 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PUNI'}
# Dokumen Ke-453 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-454 => Data Terlebel : 9 ; Total Label : 10 ; Label Hilang : {'B_VERN', 'B_PUNI'}
# Dokumen Ke-455 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-456 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-457 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-458 => Data Terlebel : 10 ; Total Label : 10 ; Label Hilang : {'B_PUNI'}
# Dokumen Ke-459 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-460 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-461 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-462 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-463 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-464 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-465 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-466 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-467 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-468 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-469 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-470 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-471 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-472 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_DEFN'}
# Dokumen Ke-473 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_DEFN'}
# Dokumen Ke-474 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-475 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_DEFN'}
# Dokumen Ke-476 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_DEFN'}
# Dokumen Ke-477 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-478 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-479 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-480 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-481 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PUNI'}
# Dokumen Ke-482 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-483 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-484 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-485 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-486 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-487 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-488 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-489 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-490 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-491 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-492 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_DEFN'}
# Dokumen Ke-493 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-494 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-495 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-496 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PUNI'}
# Dokumen Ke-497 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-498 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-499 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-500 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-501 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_DEFN'}
# Dokumen Ke-502 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-503 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-504 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-505 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-506 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-507 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_DEFN'}
# Dokumen Ke-508 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-509 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-510 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_DEFN'}
# Dokumen Ke-511 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-512 => Data Terlebel : 9 ; Total Label : 11 ; Label Hilang : {'B_PENA', 'B_DEFN'}
# Dokumen Ke-513 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-514 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-515 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-516 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-517 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_DEFN'}
# Dokumen Ke-518 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-519 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_DEFN'}
# Dokumen Ke-520 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-521 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-522 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_DEFN'}
# Dokumen Ke-523 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_DEFN'}
# Dokumen Ke-524 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-525 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-526 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-527 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-528 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-529 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-530 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-531 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-532 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-533 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-534 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-535 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-536 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-537 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_DEFN'}
# Dokumen Ke-538 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-539 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-540 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-541 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-542 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-543 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-544 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_DEFN'}
# Dokumen Ke-545 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-546 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-547 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_TIMV'}
# Dokumen Ke-548 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-549 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-550 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-551 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-552 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-553 => Data Terlebel : 10 ; Total Label : 10 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-554 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-555 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-556 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-557 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-558 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-559 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-560 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-561 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-562 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-563 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-564 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-565 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-566 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-567 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-568 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-569 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-570 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-571 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-572 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-573 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PENA'}
# Dokumen Ke-574 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-575 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-576 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-577 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-578 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_PROS'}
# Dokumen Ke-579 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-580 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-581 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-582 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-583 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-584 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-585 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-586 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-587 => Data Terlebel : 11 ; Total Label : 10 ; Label Hilang : set()
# Dokumen Ke-588 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-589 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-590 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-591 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-592 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-593 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-594 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-595 => Data Terlebel : 9 ; Total Label : 11 ; Label Hilang : {'B_PENA', 'B_PUNI'}
# Dokumen Ke-596 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-597 => Data Terlebel : 10 ; Total Label : 11 ; Label Hilang : {'B_DEFN'}
# Dokumen Ke-598 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-599 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-600 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# Dokumen Ke-601 => Data Terlebel : 11 ; Total Label : 11 ; Label Hilang : set()
# 'Accuracy : 98.04758999389873'

# %%
labels[0]
# Out:
# {'dewi ika agustina': 'B_PROS',
#  'tislan bin mukamar': 'B_DEFN',
#  'wahyu eko suryowati': 'B_JUDG',
#  'satrio budiono': 'B_JUDG',
#  '1 (satu) tahun dan 10 (sepuluh) bulan': 'B_PUNI',
#  '2 (dua) tahun 2 (dua) bulan': 'B_PENA',
#  '48/pid.b/2024/pn bkl': 'B_VERN',
#  '2 mei 2024': 'B_TIMV',
#  'ernila widikartikawati': 'B_JUDP',
#  'hosnol bakri': 'B_REGI',
#  'pencurian dalam keadaan memberatkan': 'B_CRIA',
#  'pasal 363 ayat (2) kuhp': 'B_ARTV'}

# %% [markdown]
# ## tokenization

# %%
def split_token(dataset):
    dataset_copy = dataset.copy()  # Salin dataset agar tidak memodifikasi data asli
    for i, row in tqdm(dataset_copy.iterrows(), total=len(dataset_copy), desc="Processing rows"):
        for index, (text, tag) in enumerate(zip(row["text"], row["label"])):
            if tag != "O":
                token = re.findall(r'[^\/,\.():;]+|[\/\.,():;]', text)
                add_label = []
                for i in range(len(token)):
                    if 'B' in tag and not add_label:
                        add_label.append(tag)
                    else:
                        if token[i] != ';':
                            add_label.append(tag.replace('B', 'I'))
                        else:
                            add_label.append('O')

                del row["text"][index]
                del row["label"][index]
                row["text"][index:index] = token
                row["label"][index:index] = add_label
            else:
                token = re.findall(r'[^\/,\.():;]+|[\/\.,():;]', text)
                add_label = ['O'] * len(token)  # Set label 'O' untuk semua token

                del row["text"][index]
                del row["label"][index]
                row["text"][index:index] = token
                row["label"][index:index] = add_label
    return dataset_copy

splited_df = split_token(new_df)
splited_df
# Out:
# Processing rows: 100%|██████████| 602/602 [01:12<00:00,  8.25it/s]
#          doc                                               text  \
# 0      doc:1  [PUTUSAN, Nomor, 48, /, Pid, ., B, /, 2024, /,...
# 1      doc:2  [PUTUSAN, Nomor, 42, /, Pid, ., B, /, 2024, /,...
# 2      doc:3  [PUTUSAN, Nomor, 49, /, Pid, ., B, /, 2024, /,...
# 3      doc:4  [PUTUSAN, Nomor, 56, /, Pid, ., B, /, 2024, /,...
# 4      doc:5  [PUTUSAN, Nomor, 57, /, Pid, ., B, /, 2024, /,...
# ..       ...                                                ...
# 597  doc:598  [PUTUSAN, Nomor, 274, /, Pid, ., Sus, /, 2021,...
# 598  doc:599  [PUTUSAN, Nomor, 272, /, Pid, ., B, /, 2021, /...
# 599  doc:600  [PUTUSAN, Nomor, 220, /, Pid, ., Sus, /, 2021,...
# 600  doc:601  [PUTUSAN, Nomor, 293, /, Pid, ., B, /, 2021, /...
# 601  doc:602  [PUTUSAN, Nomor, 254, /, Pid, ., B, /, 2021, /...
#
#                                                  label
# 0    [O, O, B_VERN, I_VERN, I_VERN, I_VERN, I_VERN,...
# 1    [O, O, B_VERN, I_VERN, I_VERN, I_VERN, I_VERN,...
# 2    [O, O, B_VERN, I_VERN, I_VERN, I_VERN, I_VERN,...
# 3    [O, O, B_VERN, I_VERN, I_VERN, I_VERN, I_VERN,...
# 4    [O, O, B_VERN, I_VERN, I_VERN, I_VERN, I_VERN,...
# ..                                                 ...
# 597  [O, O, B_VERN, I_VERN, I_VERN, I_VERN, I_VERN,...
# 598  [O, O, B_VERN, I_VERN, I_VERN, I_VERN, I_VERN,...
# 599  [O, O, B_VERN, I_VERN, I_VERN, I_VERN, I_VERN,...
# 600  [O, O, B_VERN, I_VERN, I_VERN, I_VERN, I_VERN,...
# 601  [O, O, B_VERN, I_VERN, I_VERN, I_VERN, I_VERN,...
#
# [602 rows x 3 columns]

# %%
filtered_rows = new_df.loc[new_df['doc'] == f'doc:{1}']
text_example = []
for sentence_tokens in filtered_rows['text']:
    text_example.extend(sentence_tokens)
label_example = []
for sentence_tokens in filtered_rows['label']:
    label_example.extend(sentence_tokens)
print(text_example)
print(label_example)
# Out:
# ['PUTUSAN', 'Nomor', '48', '/', 'Pid', '.', 'B', '/', '2024', '/', 'PN', 'Bkl', 'DEMI', 'KEADILAN', 'BERDASARKAN', 'KETUHANAN', 'YANG', 'MAHA', 'ESA', 'Pengadilan', 'Negeri', 'Bangkalan', 'yang', 'mengadili', 'perkara', 'pidana', 'dengan', 'acara', 'pemeriksaan', 'biasa', 'dalam', 'tingkat', 'pertama', 'menjatuhkan', 'putusan', 'sebagai', 'berikut', 'dalam', 'perkara', 'Terdakwa', ':', '1', '.', 'Nama', 'lengkap', ':', 'Tislan', 'Bin', 'Mukamar', '2', '.', 'Tempat', 'lahir', ':', 'Bangkalan', '3', '.', 'Umur', '/', 'Tanggal', 'lahir', ':', '35', 'Tahun', '/', '12', 'April', '1989', '4', '.', 'Jenis', 'kelamin', ':', 'Laki-laki', '5', '.', 'Kebangsaan', ':', 'Indonesia', '6', '.', 'Tempat', 'tinggal', ':', 'Dsn', '.', 'Lang', 'Lebar', 'Ds', '.', 'Batobella', 'Kec', '.', 'Geger', 'Kab', '.', 'Bangkalan', '7', '.', 'Agama', ':', 'Islam', '8', '.', 'Pekerjaan', ':', 'Wiraswasta', 'Terdakwa', 'Tislan', 'Bin', 'Mukamar', 'ditahan', 'dalam', 'tahanan', 'oleh', ':', '1', '.', 'Penyidik', 'sejak', 'tanggal', '15', 'Januari', '2024', 'sampai', 'dengan', 'tanggal', '3', 'Februari', '2024', '2', '.', 'Penyid
'lembar', 'STNK', 'sepeda', 'motor', 'merk', 'Honda', 'Vario', 'warna', 'white', 'silver', 'Nopol', 'M-3728-HB', 'tahun', '2012', 'Noka', 'MH1JFB110CK005773', 'Nosin', 'JFB1E1007445', 'An', '.', 'Moh', 'Zahri', 'alamat', 'Rajawali', 'Blok', 'C1', 'No', '.', '26', 'Rw', '09', 'Rt', '01', 'kel', '.', 'Pangeranan', 'Kec', ',', '/', 'kab', '.', 'Bangkalan', '1', 'bendel', 'fotocopy', 'BPKB', 'sepeda', 'motor', 'merk', 'Honda', 'Vario', 'warna', 'white', 'silver', 'Nopol', 'M-3728-H ...
# ['O', 'O', 'B_VERN', 'I_VERN', 'I_VERN', 'I_VERN', 'I_VERN', 'I_VERN', 'I_VERN', 'I_VERN', 'I_VERN', 'I_VERN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_DEFN', 'I_DEFN', 'I_DEFN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_DEFN', 'I_DEFN', 'I_DEFN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_VERN', 'I_VERN', 'I_VERN', 'I_VERN', 'I_VERN', 'I_VERN', 'I_VERN', 'I_VERN', 'I_VERN', 'I_VERN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_VERN', 'I_VERN', 'I_VERN', 'I_VERN', 'I_VERN', 'I_VERN', 'I_VERN', 'I_VERN', 'I_VERN', 'I_VERN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_DEFN', 'I_DEFN', 'I_DEFN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_ARTV', 'I_ARTV', 'I_ARTV', 'I_ARTV', 'I_ARTV', 'I_ARTV', 'I_ARTV', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_DEFN', 'I_DEFN', 'I_DEFN', 'O', 'O', 'O', 'O', 'B_PENA', 'I_PENA', 'I_PENA', 'I_PENA', 'I_PENA', 'I_PENA', 'I_PENA', 'I_PENA', 'I_PENA', 'I_PENA', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'B_DEFN', 'I_DEFN', 'I_DEFN', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', 'O', ...

# %%
for token, label in zip(text_example, label_example):
  if label != 'O' or token == ' ':
    print(f"Token Text : {token} => {label}")
# Out:
# Token Text : 48 => B_VERN
# Token Text : / => I_VERN
# Token Text : Pid => I_VERN
# Token Text : . => I_VERN
# Token Text : B => I_VERN
# Token Text : / => I_VERN
# Token Text : 2024 => I_VERN
# Token Text : / => I_VERN
# Token Text : PN => I_VERN
# Token Text : Bkl => I_VERN
# Token Text : Tislan => B_DEFN
# Token Text : Bin => I_DEFN
# Token Text : Mukamar => I_DEFN
# Token Text : Tislan => B_DEFN
# Token Text : Bin => I_DEFN
# Token Text : Mukamar => I_DEFN
# Token Text : 48 => B_VERN
# Token Text : / => I_VERN
# Token Text : Pid => I_VERN
# Token Text : . => I_VERN
# Token Text : B => I_VERN
# Token Text : / => I_VERN
# Token Text : 2024 => I_VERN
# Token Text : / => I_VERN
# Token Text : PN => I_VERN
# Token Text : Bkl => I_VERN
# Token Text : 48 => B_VERN
# Token Text : / => I_VERN
# Token Text : Pid => I_VERN
# Token Text : . => I_VERN
# Token Text : B => I_VERN
# Token Text : / => I_VERN
# Token Text : 2024 => I_VERN
# Token Text : / => I_VERN
# Token Text : PN => I_VERN
# Token Text : Bkl => I_VERN
# Token Text : TISLAN => B_DEFN
# Token Text : Bin => I_DEFN
# Token Text : MUKAMAR => I_DEFN
# Token Text : Pasal => B_ARTV
# Token Text : 363 => I_ARTV
# Token Text : ayat => I_ARTV
# Token Text : ( => I_ARTV
# Token Text : 2 => I_ARTV
# Token Text : ) => I_ARTV
# Token Text : KUHP => I_ARTV
# Token Text : TISLAN => B_DEFN
# Token Text : Bin => I_DEFN
# Token Text : MUKAMAR => I_DEFN
# Token Text : 2 => B_PENA
# Token Text : ( => I_PENA
# Token Text : dua => I_PENA
# Token Text : ) => I_PENA
# Token Text : tahun => I_PENA
# Token Text : 2 => I_PENA
# Token Text : ( => I_PENA
# Token Text : dua => I_PENA
# Token Text : ) => I_PENA
# Token Text : bulan => I_PENA
# Token Text : TISLAN => B_DEFN
# Token Text : Bin => I_DEFN
# Token Text : MUKAMAR => I_DEFN
# Token Text : Pasal => B_ARTV
# Token Text : 363 => I_ARTV
# Token Text : ayat => I_ARTV
# Token Text : ( => I_ARTV
# Token Text : 2 => I_ARTV
# Token Text : ) => I_ARTV
# Token Text : KUHP => I_ARTV
# Token Text : Pasal => B_ARTV
# Token Text : 363 => I_ARTV
# Token Text : ayat => I_ARTV
# Token Text : ( => I_ARTV
# Token Text : 2 => I_ARTV
# Token Text : ) => I_ARTV
# Token Text : KUHP => I_ARTV
# Token Text : TISLAN => B_DEFN
# Token Text : BIN => I_DEFN
# Token Text : MUKAMAR => I_DEFN
# Token Text : Pasal => B_ARTV
# Token Text : 363 => I_ARTV
# Token Text : ayat => I_ARTV
# Token Text : ( => I_ARTV
# Token Text : 2 => I_ARTV
# Token Text : ) => I_ARTV
# Token Text : KUHP => I_ARTV
# Token Text : Pasal => B_ARTV
# Token Text : 363 => I_ARTV
# Token Text : ayat => I_ARTV
# Token Text : ( => I_ARTV
# Token Text : 2 => I_ARTV
# Token Text : ) => I_ARTV
# Token Text : KUHP => I_ARTV
# Token Text : TISLAN => B_DEFN
# Token Text : BIN => I_DEFN
# Token Text : MUKAMAR => I_DEFN
# Token Text : , => I_DEFN
# Token Text : Pencurian => B_CRIA
# Token Text : Dalam => I_CRIA
# Token Text : Keadaan => I_CRIA
# Token Text : Memberatkan => I_CRIA
# Token Text : 1 => B_PUNI
# Token Text : ( => I_PUNI
# Token Text : satu => I_PUNI
# Token Text : ) => I_PUNI
# Token Text : Tahun => I_PUNI
# Token Text : dan => I_PUNI
# Token Text : 10 => I_PUNI
# Token Text : ( => I_PUNI
# Token Text : sepuluh => I_PUNI
# Token Text : ) => I_PUNI
# Token Text : bulan => I_PUNI
# Token Text : Ernila => B_JUDP
# Token Text : Widikartikawati => I_JUDP
# Token Text : , => B_JUDG
# Token Text : Satrio => I_JUDG
# Token Text : Budiono => I_JUDG
# Token Text : Wahyu => B_JUDG
# Token Text : Eko => I_JUDG
# Token Text : Suryowati => I_JUDG
# Token Text : HOSNOL => B_REGI
# Token Text : BAKRI => I_REGI
# Token Text : Dewi => B_PROS
# Token Text : Ika => I_PROS
# Token Text : Agustina => I_PROS
# Token Text : , => B_JUDG
# Token Text : Satrio => I_JUDG
# Token Text : Budiono => I_JUDG
# Token Text : Ernila => B_JUDP
# Token Text : Widikartikawati => I_JUDP
# Token Text : Wahyu => B_JUDG
# Token Text : Eko => I_JUDG
# Token Text : Suryowati => I_JUDG
# Token Text : Hosnol => B_REGI
# Token Text : Bakri => I_REGI

# %% [markdown]
# ## ML representation

# %%
import pandas as pd

new_rows = []
fragment_id = 1

for _, row in splited_df.iterrows():
    fragments, labels, fragment, label = [], [], [], []

    for word, label_word in zip(row['text'], row['label']):
        if word != ';':
            fragment.append(word)
            label.append(label_word)
        else:
            if fragment:
                fragments.append(fragment)
                labels.append(label)
            fragment, label = [], []

    if fragment:
        fragments.append(fragment)
        labels.append(label)

    for i, (fragment, label) in enumerate(zip(fragments, labels), start=1):
        new_rows.append({'text': fragment, 'label': label, 'doc': row['doc'], 'fragment': f'fragment:{fragment_id}'})
        fragment_id += 1

df_perfrag = pd.DataFrame(new_rows)

df_pertoken = pd.DataFrame(
    [{'text': token, 'label': label, 'doc': row['doc'], 'fragment': row['fragment']}
     for _, row in df_perfrag.iterrows()
     for token, label in zip(row['text'], row['label'])]
)

df_pertoken = df_pertoken.rename(columns={'text': 'token'}).reindex(columns=['doc','fragment', 'token', 'label'])
df_pertoken
# Out:
#              doc        fragment      token   label
# 0          doc:1      fragment:1    PUTUSAN       O
# 1          doc:1      fragment:1      Nomor       O
# 2          doc:1      fragment:1         48  B_VERN
# 3          doc:1      fragment:1          /  I_VERN
# 4          doc:1      fragment:1        Pid  I_VERN
# ...          ...             ...        ...     ...
# 4082592  doc:602  fragment:78262   Panitera       O
# 4082593  doc:602  fragment:78262  Pengganti       O
# 4082594  doc:602  fragment:78262          ,       O
# 4082595  doc:602  fragment:78262        ttd       O
# 4082596  doc:602  fragment:78262     Suraji  B_REGI
#
# [4082597 rows x 4 columns]

# %%
PATH = '/content/drive/MyDrive/Skripsi/Code/Data'
df_pertoken.to_csv(f"{PATH}/ml_format_nopos.csv", index=False)

# %% [markdown]
# ## POS Tagging

# %%
_= !pip install flair
_= !pip install tqdm

# %%
import flair.datasets
from flair.embeddings import TokenEmbeddings, WordEmbeddings, StackedEmbeddings
from typing import List
from flair.data import Sentence
from flair.models import SequenceTagger
import re
import pandas as pd
from tqdm import tqdm
import shutil

# %% [markdown]
# ### training pos tagging model

# %%
#load data bahasa indonesia
corpus = flair.datasets.UD_INDONESIAN()

tag_type = 'upos'
tag_dictionary = corpus.make_tag_dictionary(tag_type=tag_type)

#mengubah ke embedding
embedding_types: List[TokenEmbeddings] = [
 WordEmbeddings('id-crawl'),
 WordEmbeddings('id'),
]
embeddings: StackedEmbeddings = StackedEmbeddings(embeddings=embedding_types)

tagger: SequenceTagger = SequenceTagger(hidden_size=256,
                                        embeddings=embeddings,
                                        tag_dictionary=tag_dictionary,
                                        tag_type=tag_type,
                                        use_crf=True)

#training model pos
trainer: ModelTrainer = ModelTrainer(tagger, corpus)
trainer.train('resources/taggers/example-universal-pos',
              learning_rate=0.1,
              mini_batch_size=32,
              max_epochs=10)

# Menyalin model ke Google Drive
model_path = 'resources/taggers/example-universal-pos/best-model.pt'
PATH = '/content/drive/MyDrive/Skripsi/Code'
drive_model_path = f"{PATH}/best-model.pt"
shutil.copy(model_path, drive_model_path)

# %% [markdown]
# ### pos tagging data

# %% [markdown]
# nb:
#
# untuk proses pos tagging sebaiknya dijalankan pada colab yang berbeda, karena memakan waktu lama
#
# selain itu jika data terlalu banyak, data dibagi menjadi beberapa bagian sebelum masuk pos tagging, karena jika data yang diproses terlalu banyak maka runtime colab akan putus

# %%
# PATH = '/content/drive/MyDrive/Skripsi/Code/Data'
# pos1 = pd.read_csv(f"{PATH}/pos_data1.csv")
# pos2 = pd.read_csv(f"{PATH}/pos_data2.csv")
# pos = pd.concat([pos1, pos2], ignore_index=True)
# pos

# %%
PATH = '/content/drive/MyDrive/Skripsi/Code/Data'
df = pd.read_csv(f"{PATH}/ml_format_nopos.csv")
token = df['token'].tolist()
# token1 = token[:len(token)//2]
# token2 = token[len(token)//2:]

#tag semua token data legal
model_path = '/content/drive/MyDrive/Skripsi/Code'
tag_pos = SequenceTagger.load(f"{model_path}/best-model.pt")
f_pos = []
## for every sentence ##
for i in tqdm(token):
  sentence = Sentence(str(i))
  tag_pos.predict(sentence)
  ## append tagged sentence ##
  f_pos.append(sentence.to_tagged_string())
# Out:
# 2024-07-11 00:16:08,551 SequenceTagger predicts: Dictionary with 20 tags: O, PROPN, AUX, DET, NOUN, PRON, VERB, ADP, PUNCT, ADV, CCONJ, SCONJ, NUM, ADJ, PART, SYM, INTJ, X, <START>, <STOP>
# 100%|██████████| 2041298/2041298 [2:06:54<00:00, 268.09it/s]

# %%
pos = []
for i in tqdm(f_pos):
  m = re.split(r'/', i)
  pos.append(m[-1][:-1])

df['pos'] = pos
# posdf = {"pos": pos}
# posdf = pd.DataFrame(posdf)
# posdf.to_csv(f"{PATH}/pos_data1.csv", index=False)
# Out:
# 100%|██████████| 2041298/2041298 [00:03<00:00, 589006.38it/s]

# %% [markdown]
# **proses feature engineering sampai evaluation pindah ke kaggle**

# %% [markdown]
# ## feature engineering

# %% [markdown]
# nb:
#
# untuk bagian feature engineering dan modelling sebaiknya dijalankan kaggle, karena colab free tidak mensupport komputasi yang besar
#
# kode feature engineering dan modelling terletak pada beda file

# %%
PATH2 = '/content/drive/MyDrive/Skripsi/Code/Data'
df = pd.read_csv(f"{PATH2}/data_mlformat_clean.csv")
df = df.fillna(method='ffill')
df
# Out:
#              doc        fragment      token   label    pos
# 0          doc:1      fragment:1    PUTUSAN       O  PROPN
# 1          doc:1      fragment:1      Nomor       O  PROPN
# 2          doc:1      fragment:1         48  B_VERN    NUM
# 3          doc:1      fragment:1          /  I_VERN  PUNCT
# 4          doc:1      fragment:1        Pid  I_VERN  PROPN
# ...          ...             ...        ...     ...    ...
# 1252323  doc:602  fragment:11301   Panitera       O  PROPN
# 1252324  doc:602  fragment:11301  Pengganti       O  PROPN
# 1252325  doc:602  fragment:11301          ,       O  PUNCT
# 1252326  doc:602  fragment:11301        ttd       O  PROPN
# 1252327  doc:602  fragment:11301     Suraji  B_REGI  PROPN
#
# [1252328 rows x 5 columns]

# %%
class FragmentGetter(object):

    def __init__(self, data):
        self.n_frag = 1
        self.data = data
        self.empty = False
        agg_func = lambda f: [(t, p, l) for t, p, l in
                              zip(f['token'].values.tolist(),
                                  f['pos'].values.tolist(),
                                  f['label'].values.tolist())]
        self.grouped = self.data.groupby('fragment').apply(agg_func)
        self.fragments = [f for f in self.grouped]

    def get_next(self):
        try:
            f = self.grouped['Fragment: {}'.format(self.n_frag)]
            self.n_frag += 1
            return f
        except:
            return None

# %%
def token2features(frag, i):
    token = frag[i][0]
    postag = frag[i][1]

    features = {
        'bias': 1.0,
        'token.lower()': token.lower(),
        'token.isupper()': token.isupper(),
        'token.istitle()': token.istitle(),
        'token.isdigit()': token.isdigit(),
        'postag': postag,
    }

    # Features for previous token
    if i > 0:
        features.update({
            'prev1.lower()': frag[i-1][0].lower(),
            'prev1.postag': frag[i-1][1],
        })
    else:
        features['BOF'] = True  # Beginning of fragment

    if i > 1:
        features.update({
            'prev2.lower()': frag[i-2][0].lower(),
            'prev2.postag': frag[i-2][1],
        })

    # Features for next token
    if i < len(frag) - 1:
        features.update({
            'next1.lower()': frag[i+1][0].lower(),
            'next1.postag': frag[i+1][1],
        })
    else:
        features['EOF'] = True  # End of fragment

    if i < len(frag) - 2:
        features.update({
            'next2.lower()': frag[i+2][0].lower(),
            'next2.postag': frag[i+2][1],
        })

    return features

def frag2features(frag):
  return [token2features(frag, i) for i in range(len(frag))]
def frag2labels(frag):
  return [label for token, postag, label in frag]

# %%
X_crf = df.drop(['doc'], axis=1)
getter = FragmentGetter(X_crf)
fragments = getter.fragments

X = [frag2features(f) for f in fragments]
y = [frag2labels(f) for f in fragments]

# %% [markdown]
# # Modelling

# %%
_= !pip install sklearn-crfsuite
_= !pip install jcopml
_= !pip install eli5

# %%
import sklearn
from sklearn.model_selection import train_test_split
import sklearn_crfsuite
from sklearn_crfsuite import CRF
from sklearn_crfsuite.utils import flatten
from sklearn_crfsuite import scorers
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, multilabel_confusion_matrix

# %%
import pandas as pd
import numpy as np

# Mengumpulkan data per dokumen
docs = df['doc'].unique().tolist()

# Mengacak dokumen
np.random.seed(42)  # Untuk reproduktibilitas, bisa diubah sesuai kebutuhan
np.random.shuffle(docs)

# Menentukan batas dokumen terakhir untuk training (70% dari total dokumen)
train_doc_count = int(len(docs) * 0.7)
train_docs = docs[:train_doc_count]

# Membuat DataFrame untuk data train
train_df = df[df['doc'].isin(train_docs)]

# Mencari fragment terakhir dari data train
id_last_frag = train_df['fragment'].unique().tolist()[-1]
last_frag = int(id_last_frag.split(':')[1])

# Memotong data menjadi training dan testing set berdasarkan indeks terakhir
X_train = X[:last_frag+1]
y_train = y[:last_frag+1]
X_test = X[last_frag+1:]
y_test = y[last_frag+1:]

# Mengecek hasil
print(f'Total dokumen: {len(docs)}')
print(f'Total dokumen training: {train_doc_count}')
print(f'Index fragment terakhir untuk training: {last_frag}')

# %%
import time

crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=100,
    all_possible_transitions=True
)
crf_start = time.time()
crf.fit(X_train, y_train)
crf_end = time.time()
print(f'{(crf_end - crf_start):.2f} Detik.')

# %% [markdown]
# # Evaluation

# %%
y_pred= crf.predict(X_test)
y_test_flat = [label for sent in y_test for label in sent]
y_pred_flat = [label for sent in y_pred for label in sent]

# change label to list
y = df.label.values
classes = np.unique(y)
classes = classes.tolist()

# Buat confusion matrix
cm = confusion_matrix(y_test_flat, y_pred_flat, labels=classes)

# Visualisasikan confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=classes, yticklabels=classes, cmap='Blues')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()

print(classification_report(y_test_flat, y_pred_flat, labels=classes))
# Out:
#               precision    recall  f1-score   support
#
#       B_ARTV       0.86      0.72      0.78       276
#       B_CRIA       0.85      0.63      0.72       361
#       B_DEFN       0.90      0.91      0.91      1082
#       B_JUDP       0.83      0.67      0.74       117
#        B_JUG       0.88      0.86      0.87       197
#       B_PENA       0.84      0.94      0.89        51
#       B_PROS       1.00      1.00      1.00        47
#       B_PUNI       0.92      0.82      0.87        83
#       B_REGI       0.95      0.79      0.86       110
#       B_TIMV       0.78      0.62      0.69        61
#       B_VERN       0.91      0.96      0.93       116
#       I_ARTV       0.81      0.56      0.66      2369
#       I_CRIA       0.77      0.63      0.69       324
#       I_DEFN       0.86      0.91      0.88      2693
#       I_JUDP       0.75      0.52      0.62       202
#        I_JUG       0.81      0.91      0.86       416
#       I_PENA       0.85      0.95      0.90       299
#       I_PROS       0.91      0.99      0.95        95
#       I_PUNI       0.89      0.82      0.85       475
#       I_REGI       0.89      0.78      0.83       184
#       I_TIMV       0.75      0.59      0.66       149
#       I_VERN       0.91      0.96      0.93      1093
#            O       1.00      1.00      1.00    527688
#
#     accuracy                           0.99    538488
#    macro avg       0.87      0.81      0.83    538488
# weighted avg       0.99      0.99      0.99    538488

# %%
_= !pip install eli5

# %% [markdown]
# # Testing

# %%
_= !pip install PyPDF2
_= !pip install tqdm
_= !pip install jcopml
_= !pip install fuzzywuzzy python-Levenshtein
_= !pip install sklearn-crfsuite

# %%
import requests
import PyPDF2
import re
import pandas as pd
import zipfile
import os
from tqdm import tqdm
import joblib

# %% [markdown]
# ## Read PDF

# %%
def clean_page(text):
    text = text.replace("Mahkamah Agung Republik Indonesia\nMahkamah Agung Republik Indonesia\nMahkamah Agung Republik Indonesia\nMahkamah Agung Republik Indonesia\nMahkamah Agung Republik Indonesia\nDirektori Putusan Mahkamah Agung Republik Indonesia\nputusan.mahkamahagung.go.id\n", "")
    text = text.replace("\nDisclaimer\nKepaniteraan Mahkamah Agung Republik Indonesia berusaha untuk selalu mencantumkan informasi paling kini dan akurat sebagai bentuk komitmen Mahkamah Agung untuk pelayanan publik, transparansi dan akuntabilitas\npelaksanaan fungsi peradilan. Namun dalam hal-hal tertentu masih dimungkinkan terjadi permasalahan teknis terkait dengan akurasi dan keterkinian informasi yang kami sajikan, hal mana akan terus kami perbaiki dari waktu kewaktu.\nDalam hal Anda menemukan inakurasi informasi yang termuat pada situs ini atau informasi yang seharusnya ada, namun belum tersedia, maka harap segera hubungi Kepaniteraan Mahkamah Agung RI melalui :\nEmail : kepaniteraan@mahkamahagung.go.id", "")
    text = text.replace("Telp : 021-384 3348 (ext.318)", "")
    text = re.sub(r'\nHalaman \d+ dari \d+ .*', '', text)
    text = re.sub(r'Halaman \d+ dari \d+ .*', '', text)
    text = re.sub(r'\nHal. \d+ dari \d+ .*', '', text)
    text = re.sub(r'Hal. \d+ dari \d+ .*', '', text)
    return text.strip()

def read_pdf(file_pdf):
  try:
    pdf_text = ''
    pdf_file = open(file_pdf, 'rb')
    pdf_reader = PyPDF2.PdfReader(pdf_file)

    for page_num in range(len(pdf_reader.pages)):
        page = pdf_reader.pages[page_num]
        text = clean_page(page.extract_text())
        # text = page.extract_text()

        pdf_text += ' ' + text

    pdf_file.close()
    return pdf_text.strip()

  except requests.exceptions.RequestException as e:
    print("Error:", e)

# %% [markdown]
# ## Preprocessing

# %%
def clean_text(text):
    text = text.replace('P U T U S A N', 'PUTUSAN').replace('T erdakwa', 'Terdakwa').replace('T empat', 'Tempat').replace('T ahun', 'Tahun')
    text = text.replace('P  E  N  E  T  A  P  A  N', 'PENETAPAN').replace('J u m l a h', 'Jumlah').replace('M E N G A D I L I', 'MENGADILI')
    text = re.sub(r'Halaman \d+', ' ', text)
    text = text.replace('\uf0d8', '').replace('\uf0b7', '').replace('\n', ' ')
    text = re.sub(r'([“”"])', r' \1 ', text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

# %% [markdown]
# ## Representasi CRF

# %%
def representation_crf(text, id_fragment):
    content_results = {"doc": [], "fragment": [], "token": []}

    fragments = text.split(';')

    for fragment_idx, fragment in enumerate(fragments):
        fragment_str = f"fragment:{id_fragment}"
        doc_str = f"doc:1"

        fragment = re.sub(r'([\/,\.():;])', r' \1 ', fragment)
        tokens = re.findall(r'\S+', fragment)

        for token in tokens:
            content_results["doc"].append(doc_str)
            content_results["fragment"].append(fragment_str)
            content_results["token"].append(token)

    new_data = pd.DataFrame(content_results)

    return new_data

# %% [markdown]
# ## Testing

# %%
class FragmentGetter(object):

    def __init__(self, data):
        self.n_frag = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(a) for a in zip(s['token'].values.tolist(),
        # agg_func = lambda s: [(a, b) for a, b in zip(s['token'].values.tolist(),
                                                    # s['pos'].values.tolist(),
                                                     )]
        self.grouped = self.data.groupby('fragment').apply(agg_func)
        self.fragments = [f for f in self.grouped]

    def get_next(self):
        try:
            f = self.grouped['Fragment: {}'.format(self.n_frag)]
            self.n_frag += 1
            return f
        except:
            return None

# %%
def token2features(frag, i):
    token = frag[i][0]
    # postag = frag[i][1]

    features = {
        'bias': 1.0,
        'token':token,
        # 'token.lower()': token.lower(),
        # 'token.isupper()': token.isupper(),
        # 'token.istitle()': token.istitle(),
        # 'token.isdigit()': token.isdigit(),
        # 'postag': postag,
    }

    # Features for previous token
    if i > 0:
        features.update({
            'prev1': frag[i-1][0],
            # 'prev1.lower()': frag[i-1][0].lower(),
            # 'prev1.isupper()': frag[i-1][0].isupper(),
            # 'prev1.istitle()': frag[i-1][0].istitle(),
            # 'prev1.isdigit()': frag[i-1][0].isdigit(),
            # 'prev1.postag': frag[i-1][1],
        })
    else:
        features['BOF'] = True  # Beginning of fragment

    if i > 1:
        features.update({
            'prev2': frag[i-2][0],
            # 'prev2.lower()': frag[i-2][0].lower(),
            # 'prev2.isupper()': frag[i-2][0].isupper(),
            # 'prev2.istitle()': frag[i-2][0].istitle(),
            # 'prev2.isdigit()': frag[i-2][0].isdigit(),
            # 'prev2.postag': frag[i-2][1],
        })

    # Features for next token
    if i < len(frag) - 1:
        features.update({
            'next1': frag[i+1][0],
            # 'next1.lower()': frag[i+1][0].lower(),
            # 'next1.isupper()': frag[i+1][0].isupper(),
            # 'next1.istitle()': frag[i+1][0].istitle(),
            # 'next1.isdigit()': frag[i+1][0].isdigit(),
            # 'next1.postag': frag[i+1][1],
        })
    else:
        features['EOF'] = True  # End of fragment

    if i < len(frag) - 2:
        features.update({
            'next2': frag[i+2][0],
            # 'next2.lower()': frag[i+2][0].lower(),
            # 'next2.isupper()': frag[i+2][0].isupper(),
            # 'next2.istitle()': frag[i+2][0].istitle(),
            # 'next2.isdigit()': frag[i+2][0].isdigit(),
            # 'next2.postag': frag[i+2][1],
        })

    return features

def frag2features(frag):
  return [token2features(frag, i) for i in range(len(frag))]
def frag2labels(frag):
  return [label for token, label in frag]
  # return [label for token, postag, label in frag]

# %%
def check_entity(df, doc_idx):
    filtered_rows = df.loc[df['doc'] == f'doc:{doc_idx}']

    tokens = filtered_rows['token'].tolist()
    labels = filtered_rows['label'].tolist()

    entities = {}
    current_entity = ''
    current_label = ''

    for token, label in zip(tokens, labels):
        if label == 'O':
            continue

        entity_type = label.split('_')[-1]

        if label.startswith('B_'):
            if current_label:
                if current_label not in entities:
                    entities[current_label] = []
                entities[current_label].append(current_entity.strip())

            current_entity = token
            current_label = entity_type

        elif label.startswith('I_') and current_label == entity_type:
            current_entity += ' ' + token

    # Menambahkan entitas terakhir ke dalam dictionary
    if current_label:
        if current_label not in entities:
            entities[current_label] = []
        entities[current_label].append(current_entity.strip())

    for entity_type, entity_list in entities.items():
        for entity in entity_list:
            print(f"{entity_type} = {entity}")

# %% [markdown]
# ## Main test

# %%
from fuzzywuzzy import fuzz
# ------------------------------------------------- read file
pdf_path = 'file.pdf'
content = read_pdf(pdf_path)
content = clean_text(content)

# Define the paths
PATH2 = '/content/drive/MyDrive/Skripsi/Code'
model_path = f'{PATH2}/600crf.pkl'
# model_path = f'{PATH2}/600crf_prevnext.pkl'

# Split content into sentences
pecahan = (content).split(';')

# Function to process a single sentence and return the resulting data
def process_sentence(sentence, id_fragment):
    data = representation_crf(sentence, id_fragment)

    # Feature engineering
    X_crf = data.drop(['doc'], axis=1)
    getter = FragmentGetter(X_crf)
    fragments = getter.fragments
    X = [frag2features(f) for f in fragments]

    # Predict
    crf = joblib.load(model_path)
    y_pred = crf.predict(X)

    # Input label to dataset
    flat_predictions = [tag for sentence_tags in y_pred for tag in sentence_tags]
    assert len(flat_predictions) == len(data['token'])
    data['label'] = flat_predictions

    return data

# Function to check entities and collect them
def check_entity(df):
    tokens = df['token'].tolist()
    labels = df['label'].tolist()

    entities = {}
    current_entity = ''
    current_label = ''

    for token, label in zip(tokens, labels):
        if label == 'O':
            continue

        entity_type = label.split('_')[-1]

        if label.startswith('B_'):
            if current_label:
                if current_label not in entities:
                    entities[current_label] = set()
                entities[current_label].add(current_entity.strip())

            current_entity = token
            current_label = entity_type

        elif label.startswith('I_') and current_label == entity_type:
            current_entity += ' ' + token

    # Menambahkan entitas terakhir ke dalam dictionary
    if current_label:
        if current_label not in entities:
            entities[current_label] = set()
        entities[current_label].add(current_entity.strip())

    return entities

# Collect results from each sentence
results = []
all_entities = {}
print(len(pecahan))

count = 1
for kalimat in pecahan:
    result = process_sentence(kalimat, count)
    results.append(result)
    count += 1

    # Extract and collect entities
    entities = check_entity(result)
    for entity_type, entity_set in entities.items():
        if entity_type not in all_entities:
            all_entities[entity_type] = set()
        all_entities[entity_type].update(entity_set)

    # Combine all results into a single DataFrame
df = pd.concat(results, ignore_index=True)

# Convert the entities dictionary to a list of tuples and remove duplicates
final_entities = {entity_type: list(entity_set) for entity_type, entity_set in all_entities.items()}

key_mapping = {
    "VERN": "Nomor Putusan",
    "DEFN": "Terdakwa",
    "CRIA": "Tindak pidana",
    "PENA": "Tuntutan Hukuman",
    "ARTV": "Pasal yang Dilanggar",
    "PUNI": "Putusan Hukuman",
    "JUDP": "Hakim Ketua",
    "JUDG": "Hakim Anggota",
    "TIMV": "Tanggal Perkara",
    "REGI": "Panitera",
    "PROS": "Penuntut Umum"
}

def remove_similar(items, threshold=80):
    unique_items = []
    for item in items:
        is_covered = False
        for other_item in unique_items:
            if fuzz.partial_ratio(item, other_item) > threshold:
                is_covered = True
                # Keep the longer item if similar
                if len(item) > len(other_item):
                    unique_items.remove(other_item)
                    unique_items.append(item)
                break
        if not is_covered:
            unique_items.append(item)
    return unique_items

for entity in final_entities:
    final_entities[entity] = remove_similar(final_entities[entity])

for key, value in final_entities.items():
    deskripsi = key_mapping.get(key, key)
    print(f"{deskripsi}: {' | '.join(value)}")
# Out:
# 72
# Nomor Putusan: 5 / Pid . B / 2024 / PN Smp
# Terdakwa: AKHMAD ROFI’I Als . OPEK Bin M . ZAINUDDIN | AFRIZAL DWI RAMDHANI Bin
# Tindak pidana: dengan hak subyektif orang lain , bertentangan dengan hak subjektif orang lain , bertentangan dengan kesusilaan , bertentangan dengan kepatutan , ketelitian dan kehati-hatian | Penipuan | gelang emas berat 12 , 650 gram dan kalung emas berat 8 , 940 gram , selanjutnya cincin emas berat 2 gram , cincin emas 4 , 830 gram dan gantungan kalung berat 1 , 550 gram , gelang emas rantai berat 12 , 180 gram ,
# Pasal yang Dilanggar: Pasal 378 juncto Pasal 55 ayat ( 1 ) ke-1 Kitab Undang- Undang Hukum Pidana , Undang-Undang Republik Indonesia | Pasal 378 KUHP Jo . Pasal 55 Ayat ( 1 ) ke 1 KUHP | pasal 378 Kitab Undang – Undang Hukum Pidana Pasal 55 Ayat ( 1 ) ke 1 KUHP | Pasal 193 ayat ( 1 ) Kitab Undang-Undang Hukum Acara Pidana ( KUHAP ) ,
# Tuntutan Hukuman: 2 ( dua ) tahun dan 6 ( enam ) bulan
# Panitera: Nani Irianingsih | Akhmad Rofi’i
# Putusan Hukuman: 1 ( satu ) tahun 6 ( enam ) bulan
# Hakim Ketua: Quraisyiyah
# Hakim Anggota: Muhammad Arief Fatony
# Penuntut Umum: Nur Fajjriyah

# %%
def remove_rows_with_all_O(df):
    df_filtered = df[~df.groupby(['doc', 'fragment'])['label'].transform(lambda x: all(label == 'O' for label in x))]
    df_filtered = df_filtered.reset_index(drop=True)
    return df_filtered

# Menghapus data yang memenuhi kondisi
filtered_data = remove_rows_with_all_O(df)
filtered_data.tail()
# Out:
#         doc     fragment token label
# 8558  doc:1  fragment:72     ,     O
# 8559  doc:1  fragment:72     S     O
# 8560  doc:1  fragment:72     .     O
# 8561  doc:1  fragment:72     H     O
# 8562  doc:1  fragment:72     .     O

# %%
unique_counts = df.nunique()
print(unique_counts)
# Out:
# doc            1
# fragment      72
# token       1387
# label         20
# dtype: int64

# %% [markdown]
# # App

# %%
_= !pip install gradio fuzzywuzzy joblib PyPDF2 sklearn-crfsuite

# %%
import re
import joblib
import pandas as pd
import PyPDF2
import gradio as gr
from fuzzywuzzy import fuzz

PATH2 = '/content/drive/MyDrive/Skripsi/Code'
model_path = f'{PATH2}/600crf_prevnext.pkl'

# Function to clean the page
def clean_page(text):
    text = text.replace("Mahkamah Agung Republik Indonesia\nMahkamah Agung Republik Indonesia\nMahkamah Agung Republik Indonesia\nMahkamah Agung Republik Indonesia\nMahkamah Agung Republik Indonesia\nDirektori Putusan Mahkamah Agung Republik Indonesia\nputusan.mahkamahagung.go.id\n", "")
    text = text.replace("\nDisclaimer\nKepaniteraan Mahkamah Agung Republik Indonesia berusaha untuk selalu mencantumkan informasi paling kini dan akurat sebagai bentuk komitmen Mahkamah Agung untuk pelayanan publik, transparansi dan akuntabilitas\npelaksanaan fungsi peradilan. Namun dalam hal-hal tertentu masih dimungkinkan terjadi permasalahan teknis terkait dengan akurasi dan keterkinian informasi yang kami sajikan, hal mana akan terus kami perbaiki dari waktu kewaktu.\nDalam hal Anda menemukan inakurasi informasi yang termuat pada situs ini atau informasi yang seharusnya ada, namun belum tersedia, maka harap segera hubungi Kepaniteraan Mahkamah Agung RI melalui :\nEmail : kepaniteraan@mahkamahagung.go.id", "")
    text = text.replace("Telp : 021-384 3348 (ext.318)", "")
    text = re.sub(r'\nHalaman \d+ dari \d+ .*', '', text)
    text = re.sub(r'Halaman \d+ dari \d+ .*', '', text)
    text = re.sub(r'\nHal. \d+ dari \d+ .*', '', text)
    text = re.sub(r'Hal. \d+ dari \d+ .*', '', text)
    return text.strip()

# Function to read and clean text from PDF
def read_pdf(file_pdf):
    try:
        pdf_text = ''
        pdf_file = open(file_pdf, 'rb')
        pdf_reader = PyPDF2.PdfReader(pdf_file)

        for page_num in range(len(pdf_reader.pages)):
            page = pdf_reader.pages[page_num]
            text = clean_page(page.extract_text())
            pdf_text += ' ' + text

        pdf_file.close()
        return pdf_text.strip()

    except Exception as e:
        print("Error:", e)

# Function to clean the text
def clean_text(text):
    text = text.replace('P U T U S A N', 'PUTUSAN').replace('T erdakwa', 'Terdakwa').replace('T empat', 'Tempat').replace('T ahun', 'Tahun')
    text = text.replace('P  E  N  E  T  A  P  A  N', 'PENETAPAN').replace('J u m l a h', 'Jumlah').replace('M E N G A D I L I', 'MENGADILI')
    text = re.sub(r'Halaman \d+', ' ', text)
    text = text.replace('\uf0d8', '').replace('\uf0b7', '').replace('\n', ' ')
    text = re.sub(r'([“”"])', r' \1 ', text)
    text = re.sub(r'\s+', ' ', text)
    return text.strip()

# Function for CRF representation
def representation_crf(text):
    content_results = {"doc": [], "fragment": [], "token": []}

    fragments = text.split(';')

    for fragment_idx, fragment in enumerate(fragments):
        fragment_str = f"fragment:{fragment_idx}"
        doc_str = f"doc:1"

        fragment = re.sub(r'([\/,\.():;])', r' \1 ', fragment)
        tokens = re.findall(r'\S+', fragment)

        for token in tokens:
            content_results["doc"].append(doc_str)
            content_results["fragment"].append(fragment_str)
            content_results["token"].append(token)

    new_data = pd.DataFrame(content_results)

    return new_data

# Fragment getter class
class FragmentGetter(object):

    def __init__(self, data):
        self.n_frag = 1
        self.data = data
        self.empty = False
        agg_func = lambda s: [(a) for (a) in zip(s['token'].values.tolist())]
        self.grouped = self.data.groupby('fragment').apply(agg_func)
        self.fragments = [f for f in self.grouped]

    def get_next(self):
        try:
            f = self.grouped['Fragment: {}'.format(self.n_frag)]
            self.n_frag += 1
            return f
        except:
            return None

# Function to convert token to features
def token2features(frag, i):
    token = frag[i][0]

    features = {
        'bias': 1.0,
        'token': token
    }

    # Features for previous token
    if i > 0:
        features.update({
            'prev1': frag[i - 1][0]

        })
    else:
        features['BOF'] = True  # Beginning of fragment

    if i > 1:
        features.update({
            'prev2': frag[i - 2][0]
        })

    # Features for next token
    if i < len(frag) - 1:
        features.update({
            'next1': frag[i + 1][0]
        })
    else:
        features['EOF'] = True  # End of fragment

    if i < len(frag) - 2:
        features.update({
            'next2': frag[i + 2][0]
        })

    return features

# Function to convert fragment to features
def frag2features(frag):
    return [token2features(frag, i) for i in range(len(frag))]

def frag2labels(frag):
    return [label for token, label in frag]

# Function to process a single sentence and return the resulting data
def process_sentence(sentence):
    data = representation_crf(sentence)

    # Feature engineering
    X_crf = data.drop(['doc'], axis=1)
    getter = FragmentGetter(X_crf)
    fragments = getter.fragments
    X = [frag2features(f) for f in fragments]

    # Predict
    crf = joblib.load(model_path)
    y_pred = crf.predict(X)

    # Input label to dataset
    flat_predictions = [tag for sentence_tags in y_pred for tag in sentence_tags]
    assert len(flat_predictions) == len(data['token'])
    data['label'] = flat_predictions

    return data

# Function to check entities and collect them
def check_entity(df):
    tokens = df['token'].tolist()
    labels = df['label'].tolist()

    entities = {}
    current_entity = ''
    current_label = ''

    for token, label in zip(tokens, labels):
        if label == 'O':
            continue

        entity_type = label.split('_')[-1]

        if label.startswith('B_'):
            if current_label:
                if current_label not in entities:
                    entities[current_label] = set()
                entities[current_label].add(current_entity.strip())

            current_entity = token
            current_label = entity_type

        elif label.startswith('I_') and current_label == entity_type:
            current_entity += ' ' + token

    # Add the last entity to the dictionary
    if current_label:
        if current_label not in entities:
            entities[current_label] = set()
        entities[current_label].add(current_entity.strip())

    return entities


# Function to format the entities for display
def format_entities(entities):
    key_mapping = {
        "VERN": "Nomor Putusan",
        "DEFN": "Terdakwa",
        "CRIA": "Tindak pidana",
        "PENA": "Tuntutan Hukuman",
        "ARTV": "Pasal yang Dilanggar",
        "PUNI": "Putusan Hukuman",
        "JUDP": "Hakim Ketua",
        "JUDG": "Hakim Anggota",
        "TIMV": "Tanggal Perkara",
        "REGI": "Panitera",
        "PROS": "Penuntut Umum"
    }

    def remove_similar(items, threshold=80):
        unique_items = []
        for item in items:
            is_covered = False
            for other_item in unique_items:
                if fuzz.partial_ratio(item, other_item) > threshold:
                    is_covered = True
                    # Keep the longer item if similar
                    if len(item) > len(other_item):
                        unique_items.remove(other_item)
                        unique_items.append(item)
                    break
            if not is_covered:
                unique_items.append(item)
        return unique_items

    for entity in entities:
        entities[entity] = remove_similar(entities[entity])

    formatted_entities = []
    for key, value in entities.items():
        deskripsi = key_mapping.get(key, key)
        formatted_entities.append(f"{deskripsi}: {' | '.join(value)}")
    return '\n'.join(formatted_entities)

# Function to visualize tokens with labels using HighlightedText
def visualize_ner(df):
    tokens = df['token'].tolist()
    labels = df['label'].tolist()

    entities = []
    current_entity = ""
    current_label = ""

    for token, label in zip(tokens, labels):
        if label == "O":
            if current_entity:
                entities.append((current_entity, current_label))
                current_entity = ""
                current_label = ""
            entities.append((token, None))
        else:
            entity_type = label.split('_')[-1]
            if label.startswith('B_'):
                if current_entity:
                    entities.append((current_entity, current_label))
                current_entity = token
                current_label = entity_type
            elif label.startswith('I_') and current_label == entity_type:
                current_entity += " " + token

    if current_entity:
        entities.append((current_entity, current_label))

    return entities

# Function to process the input text
def process_text(input_text):
    pecahan = input_text.split(';')

    results = []
    all_entities = {}
    visualizations = []

    for kalimat in pecahan:
        result = process_sentence(kalimat)
        results.append(result)

        # Extract and collect entities
        entities = check_entity(result)
        for entity_type, entity_set in entities.items():
            if entity_type not in all_entities:
                all_entities[entity_type] = set()
            all_entities[entity_type].update(entity_set)

        # Generate visualization
        visualizations.extend(visualize_ner(result))

    # Combine all results into a single DataFrame
    df = pd.concat(results, ignore_index=True)

    # Convert the entities dictionary to a list of tuples and remove duplicates
    final_entities = {entity_type: list(entity_set) for entity_type, entity_set in all_entities.items()}

    return format_entities(final_entities), visualizations

# Function to handle uploaded PDF
def process_pdf(pdf_file):
    text = read_pdf(pdf_file.name)
    return process_text(clean_text(text))

# Define Gradio interface using Blocks
with gr.Blocks() as iface:
    gr.Markdown("## Entity Extraction")
    gr.Markdown("Enter your text to extract entities or upload a PDF file.")

    with gr.Tab("Input Text"):
        text_input = gr.Textbox(label="Input Text")
        text_button = gr.Button("Extract Entities")
        text_output_entities = gr.Textbox(label="Extracted Entities", lines=10)
        text_output_visualization = gr.HighlightedText(label="Visualization")
        text_button.click(fn=process_text, inputs=text_input, outputs=[text_output_entities, text_output_visualization])

    with gr.Tab("Upload PDF"):
        pdf_input = gr.File(label="Upload PDF")
        pdf_button = gr.Button("Extract Entities")
        pdf_output_entities = gr.Textbox(label="Extracted Entities", lines=10)
        pdf_output_visualization = gr.HighlightedText(label="Visualization")
        pdf_button.click(fn=process_pdf, inputs=pdf_input, outputs=[pdf_output_entities, pdf_output_visualization])

# Launch Gradio app
iface.launch()
# Out:
# Setting queue=True in a Colab notebook requires sharing enabled. Setting `share=True` (you can turn this off by setting `share=False` in `launch()` explicitly).
#
# Colab notebook detected. To show errors in colab notebook, set debug=True in launch()
# Running on public URL: https://264860262d33a7f4cf.gradio.live
#
# This share link expires in 72 hours. For free permanent hosting and GPU upgrades, run `gradio deploy` from Terminal to deploy to Spaces (https://huggingface.co/spaces)
# <div><iframe src="https://264860262d33a7f4cf.gradio.live" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>
