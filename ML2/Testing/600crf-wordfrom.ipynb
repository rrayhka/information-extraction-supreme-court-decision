# %%
pip install gdown jcopml eli5 git+https://github.com/MeMartijn/updated-sklearn-crfsuite.git
# Out:
# Collecting git+https://github.com/MeMartijn/updated-sklearn-crfsuite.git
#   Cloning https://github.com/MeMartijn/updated-sklearn-crfsuite.git to /tmp/pip-req-build-rjf6mrwx
#   Running command git clone --filter=blob:none --quiet https://github.com/MeMartijn/updated-sklearn-crfsuite.git /tmp/pip-req-build-rjf6mrwx
#   Resolved https://github.com/MeMartijn/updated-sklearn-crfsuite.git to commit 675038761b4405f04691a83339d04903790e2b95
#   Preparing metadata (setup.py) ... done
# Collecting gdown
#   Downloading gdown-5.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting jcopml
#   Downloading jcopml-1.2.7.tar.gz (31 kB)
# done
# Requirement already satisfied: eli5 in /opt/conda/lib/python3.10/site-packages (0.13.0)
# Requirement already satisfied: beautifulsoup4 in /opt/conda/lib/python3.10/site-packages (from gdown) (4.12.2)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in /opt/conda/lib/python3.10/site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from gdown) (4.66.4)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from jcopml) (1.26.4)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from jcopml) (1.11.4)
# Requirement already satisfied: pandas in /opt/conda/lib/python3.10/site-packages (from jcopml) (2.2.2)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from jcopml) (1.2.2)
# Requirement already satisfied: matplotlib in /opt/conda/lib/python3.10/site-packages (from jcopml) (3.7.5)
# Requirement already satisfied: seaborn in /opt/conda/lib/python3.10/site-packages (from jcopml) (0.12.2)
# Requirement already satisfied: scikit-optimize in /opt/conda/lib/python3.10/site-packages (from jcopml) (0.10.1)
# Requirement already satisfied: ipywidgets in /opt/conda/lib/python3.10/site-packages (from jcopml) (7.7.1)
# Requirement already satisfied: statsmodels in /opt/conda/lib/python3.10/site-packages (from jcopml) (0.14.1)
# Collecting pyperclip (from jcopml)
#   Downloading pyperclip-1.9.0.tar.gz (20 kB)
# done
# Requirement already satisfied: attrs>17.1.0 in /opt/conda/lib/python3.10/site-packages (from eli5) (23.2.0)
# Requirement already satisfied: jinja2>=3.0.0 in /opt/conda/lib/python3.10/site-packages (from eli5) (3.1.2)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from eli5) (1.16.0)
# Requirement already satisfied: graphviz in /opt/conda/lib/python3.10/site-packages (from eli5) (0.20.3)
# Requirement already satisfied: tabulate>=0.7.7 in /opt/conda/lib/python3.10/site-packages (from eli5) (0.9.0)
# Collecting python-crfsuite>=0.8.3 (from sklearn-crfsuite==0.3.6)
#   Downloading python_crfsuite-0.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (4.2 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2>=3.0.0->eli5) (2.1.3)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->jcopml) (1.4.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->jcopml) (3.2.0)
# Requirement already satisfied: soupsieve>1.2 in /opt/conda/lib/python3.10/site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: ipykernel>=4.5.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets->jcopml) (6.28.0)
# Requirement already satisfied: ipython-genutils~=0.2.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets->jcopml) (0.2.0)
# Requirement already satisfied: traitlets>=4.3.1 in /opt/conda/lib/python3.10/site-packages (from ipywidgets->jcopml) (5.9.0)
# Requirement already satisfied: widgetsnbextension~=3.6.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets->jcopml) (3.6.6)
# Requirement already satisfied: ipython>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets->jcopml) (8.20.0)
# Requirement already satisfied: jupyterlab-widgets>=1.0.0 in /opt/conda/lib/python3.10/site-packages (from ipywidgets->jcopml) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->jcopml) (1.2.0)
# Requirement already satisfied: cycler>=0.10 in /opt/conda/lib/python3.10/site-packages (from matplotlib->jcopml) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->jcopml) (4.47.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->jcopml) (1.4.5)
# Requirement already satisfied: packaging>=20.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->jcopml) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /opt/conda/lib/python3.10/site-packages (from matplotlib->jcopml) (9.5.0)
# Requirement already satisfied: pyparsing>=2.3.1 in /opt/conda/lib/python3.10/site-packages (from matplotlib->jcopml) (3.1.1)
# Requirement already satisfied: python-dateutil>=2.7 in /opt/conda/lib/python3.10/site-packages (from matplotlib->jcopml) (2.9.0.post0)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas->jcopml) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.7 in /opt/conda/lib/python3.10/site-packages (from pandas->jcopml) (2023.4)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (3.6)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.26.18)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (2024.2.2)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in /opt/conda/lib/python3.10/site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: pyaml>=16.9 in /opt/conda/lib/python3.10/site-packages (from scikit-optimize->jcopml) (24.4.0)
# Requirement already satisfied: patsy>=0.5.4 in /opt/conda/lib/python3.10/site-packages (from statsmodels->jcopml) (0.5.6)
# Requirement already satisfied: comm>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->jcopml) (0.2.1)
# Requirement already satisfied: debugpy>=1.6.5 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->jcopml) (1.8.0)
# Requirement already satisfied: jupyter-client>=6.1.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->jcopml) (7.4.9)
# Requirement already satisfied: jupyter-core!=5.0.*,>=4.12 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->jcopml) (5.7.1)
# Requirement already satisfied: matplotlib-inline>=0.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->jcopml) (0.1.6)
# Requirement already satisfied: nest-asyncio in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->jcopml) (1.5.8)
# Requirement already satisfied: psutil in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->jcopml) (5.9.3)
# Requirement already satisfied: pyzmq>=24 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->jcopml) (24.0.1)
# Requirement already satisfied: tornado>=6.1 in /opt/conda/lib/python3.10/site-packages (from ipykernel>=4.5.1->ipywidgets->jcopml) (6.3.3)
# Requirement already satisfied: decorator in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->jcopml) (5.1.1)
# Requirement already satisfied: jedi>=0.16 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->jcopml) (0.19.1)
# Requirement already satisfied: prompt-toolkit<3.1.0,>=3.0.41 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->jcopml) (3.0.42)
# Requirement already satisfied: pygments>=2.4.0 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->jcopml) (2.17.2)
# Requirement already satisfied: stack-data in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->jcopml) (0.6.2)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->jcopml) (1.2.0)
# Requirement already satisfied: pexpect>4.3 in /opt/conda/lib/python3.10/site-packages (from ipython>=4.0.0->ipywidgets->jcopml) (4.8.0)
# Requirement already satisfied: PyYAML in /opt/conda/lib/python3.10/site-packages (from pyaml>=16.9->scikit-optimize->jcopml) (6.0.1)
# Requirement already satisfied: notebook>=4.4.1 in /opt/conda/lib/python3.10/site-packages (from widgetsnbextension~=3.6.0->ipywidgets->jcopml) (6.5.4)
# Requirement already satisfied: parso<0.9.0,>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from jedi>=0.16->ipython>=4.0.0->ipywidgets->jcopml) (0.8.3)
# Requirement already satisfied: entrypoints in /opt/conda/lib/python3.10/site-packages (from jupyter-client>=6.1.12->ipykernel>=4.5.1->ipywidgets->jcopml) (0.4)
# Requirement already satisfied: platformdirs>=2.5 in /opt/conda/lib/python3.10/site-packages (from jupyter-core!=5.0.*,>=4.12->ipykernel>=4.5.1->ipywidgets->jcopml) (3.11.0)
# Requirement already satisfied: argon2-cffi in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (23.1.0)
# Requirement already satisfied: nbformat in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (5.9.2)
# Requirement already satisfied: nbconvert>=5 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (6.4.5)
# Requirement already satisfied: Send2Trash>=1.8.0 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (1.8.2)
# Requirement already satisfied: terminado>=0.8.3 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.18.0)
# Requirement already satisfied: prometheus-client in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.19.0)
# Requirement already satisfied: nbclassic>=0.4.7 in /opt/conda/lib/python3.10/site-packages (from notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (1.0.0)
# Requirement already satisfied: ptyprocess>=0.5 in /opt/conda/lib/python3.10/site-packages (from pexpect>4.3->ipython>=4.0.0->ipywidgets->jcopml) (0.7.0)
# Requirement already satisfied: wcwidth in /opt/conda/lib/python3.10/site-packages (from prompt-toolkit<3.1.0,>=3.0.41->ipython>=4.0.0->ipywidgets->jcopml) (0.2.13)
# Requirement already satisfied: executing>=1.2.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets->jcopml) (2.0.1)
# Requirement already satisfied: asttokens>=2.1.0 in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets->jcopml) (2.4.1)
# Requirement already satisfied: pure-eval in /opt/conda/lib/python3.10/site-packages (from stack-data->ipython>=4.0.0->ipywidgets->jcopml) (0.2.2)
# Requirement already satisfied: jupyter-server>=1.8 in /opt/conda/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (2.12.5)
# Requirement already satisfied: notebook-shim>=0.2.3 in /opt/conda/lib/python3.10/site-packages (from nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.2.3)
# Requirement already satisfied: mistune<2,>=0.8.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.8.4)
# Requirement already satisfied: jupyterlab-pygments in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.3.0)
# Requirement already satisfied: bleach in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (6.1.0)
# Requirement already satisfied: pandocfilters>=1.4.1 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (1.5.0)
# Requirement already satisfied: testpath in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.6.0)
# Requirement already satisfied: defusedxml in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.7.1)
# Requirement already satisfied: nbclient<0.6.0,>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.5.13)
# Requirement already satisfied: fastjsonschema in /opt/conda/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (2.19.1)
# Requirement already satisfied: jsonschema>=2.6 in /opt/conda/lib/python3.10/site-packages (from nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (4.20.0)
# Requirement already satisfied: argon2-cffi-bindings in /opt/conda/lib/python3.10/site-packages (from argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (21.2.0)
# Requirement already satisfied: jsonschema-specifications>=2023.03.6 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (2023.12.1)
# Requirement already satisfied: referencing>=0.28.4 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.32.1)
# Requirement already satisfied: rpds-py>=0.7.1 in /opt/conda/lib/python3.10/site-packages (from jsonschema>=2.6->nbformat->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.16.2)
# Requirement already satisfied: anyio>=3.1.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (4.2.0)
# Requirement already satisfied: jupyter-events>=0.9.0 in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.9.0)
# Requirement already satisfied: jupyter-server-terminals in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.5.1)
# Requirement already satisfied: overrides in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (7.4.0)
# Requirement already satisfied: websocket-client in /opt/conda/lib/python3.10/site-packages (from jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (1.7.0)
# Requirement already satisfied: cffi>=1.0.1 in /opt/conda/lib/python3.10/site-packages (from argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (1.16.0)
# Requirement already satisfied: webencodings in /opt/conda/lib/python3.10/site-packages (from bleach->nbconvert>=5->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.5.1)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (1.3.0)
# Requirement already satisfied: typing-extensions>=4.1 in /opt/conda/lib/python3.10/site-packages (from anyio>=3.1.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (4.9.0)
# Requirement already satisfied: pycparser in /opt/conda/lib/python3.10/site-packages (from cffi>=1.0.1->argon2-cffi-bindings->argon2-cffi->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (2.21)
# Requirement already satisfied: python-json-logger>=2.0.4 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (2.0.7)
# Requirement already satisfied: rfc3339-validator in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.1.4)
# Requirement already satisfied: rfc3986-validator>=0.1.1 in /opt/conda/lib/python3.10/site-packages (from jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (0.1.1)
# Requirement already satisfied: fqdn in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (1.5.1)
# Requirement already satisfied: isoduration in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (20.11.0)
# Requirement already satisfied: jsonpointer>1.13 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (2.4)
# Requirement already satisfied: uri-template in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (1.3.0)
# Requirement already satisfied: webcolors>=1.11 in /opt/conda/lib/python3.10/site-packages (from jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (1.13)
# Requirement already satisfied: arrow>=0.15.0 in /opt/conda/lib/python3.10/site-packages (from isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (1.3.0)
# Requirement already satisfied: types-python-dateutil>=2.8.10 in /opt/conda/lib/python3.10/site-packages (from arrow>=0.15.0->isoduration->jsonschema[format-nongpl]>=4.18.0->jupyter-events>=0.9.0->jupyter-server>=1.8->nbclassic>=0.4.7->notebook>=4.4.1->widgetsnbextension~=3.6.0->ipywidgets->jcopml) (2.8.19.20240106)
# Downloading gdown-5.2.0-py3-none-any.whl (18 kB)
# Downloading python_crfsuite-0.9.10-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.1/1.1 MB 15.7 MB/s eta 0:00:00
# Building wheels for collected packages: jcopml, sklearn-crfsuite, pyperclip
# done
#   Created wheel for jcopml: filename=jcopml-1.2.7-py2.py3-none-any.whl size=45917 sha256=50921afe528e326976352f0bb6fe4e313be59d2ddb81b0fcb81be55aadce3452
#   Stored in directory: /root/.cache/pip/wheels/1b/f0/69/8cd4944dd9637953ab744056b5faa32617cd4de449b213e886
# done
#   Created wheel for sklearn-crfsuite: filename=sklearn_crfsuite-0.3.6-py2.py3-none-any.whl size=10866 sha256=9924ebdcdae5fd59331e900d256e3a4b332d2d2cb2132f1116b6d9f2c4e7b3ce
#   Stored in directory: /tmp/pip-ephem-wheel-cache-n5eyjueo/wheels/0b/bc/07/bd75a6f5fa2bf2ea05a5aad8d9ac66d2b5aab93dfd4e1a89de
# done
#   Created wheel for pyperclip: filename=pyperclip-1.9.0-py3-none-any.whl size=11002 sha256=d34d0fb262a7feb81146624fec8746301c41dcb63ec2bf863c0275dac90c9b91
#   Stored in directory: /root/.cache/pip/wheels/cc/ae/36/ee17d1de094fcb61e24106cb329b5103861e819f94bef5e10a
# Successfully built jcopml sklearn-crfsuite pyperclip
# Installing collected packages: python-crfsuite, pyperclip, sklearn-crfsuite, gdown, jcopml
# Successfully installed gdown-5.2.0 jcopml-1.2.7 pyperclip-1.9.0 python-crfsuite-0.9.10 sklearn-crfsuite-0.3.6
# Note: you may need to restart the kernel to use updated packages.

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
import pandas as pd
import numpy as np
from sklearn.feature_extraction import DictVectorizer
from sklearn.feature_extraction.text import HashingVectorizer
from sklearn.metrics import classification_report, confusion_matrix, ConfusionMatrixDisplay, multilabel_confusion_matrix
from sklearn.model_selection import cross_val_predict, cross_val_score
from jcopml.plot import plot_confusion_matrix
import seaborn as sns
import matplotlib.pyplot as plt
import time
import os
import joblib
import gdown
from functools import wraps
import sklearn_crfsuite
from sklearn_crfsuite.utils import flatten
from sklearn_crfsuite import scorers

# %%
file_id = '1-GhEOfug-V5KbvESx3ZzQOxQ8x0HIZrG'
output = 'data.csv'  
gdown.download(f"https://drive.google.com/uc?id={file_id}", output, quiet=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1-GhEOfug-V5KbvESx3ZzQOxQ8x0HIZrG
# To: /kaggle/working/data.csv
# 100%|██████████| 37.8M/37.8M [00:00<00:00, 86.2MB/s]
# 'data.csv'

# %%
df = pd.read_csv(output)
df = df.fillna('')
docs_to_drop = ['doc:2', 'doc:3']
df = df[~df['doc'].isin(docs_to_drop)]
df
# Out:
#              doc        fragment      token   label
# 0          doc:1      fragment:1    PUTUSAN       O
# 1          doc:1      fragment:1      Nomor       O
# 2          doc:1      fragment:1         48  B_VERN
# 3          doc:1      fragment:1          /  I_VERN
# 4          doc:1      fragment:1        Pid  I_VERN
# ...          ...             ...        ...     ...
# 1252323  doc:602  fragment:11301   Panitera       O
# 1252324  doc:602  fragment:11301  Pengganti       O
# 1252325  doc:602  fragment:11301          ,       O
# 1252326  doc:602  fragment:11301        ttd       O
# 1252327  doc:602  fragment:11301     Suraji  B_REGI
#
# [1249175 rows x 4 columns]

# %% [markdown]
# # CRF

# %%
class FragmentGetter(object):

    def __init__(self, data):
        self.n_frag = 1
        self.data = data
        self.empty = False
        agg_func = lambda f: [(t, l) for t, l in
#         agg_func = lambda f: [(t, p, l) for t, p, l in
                              zip(f['token'].values.tolist(),
#                                   f['pos'].values.tolist(),
                                  f['label'].values.tolist())]
        self.grouped = self.data.groupby('fragment').apply(agg_func)
        self.fragments = [f for f in self.grouped]

    def get_next(self):
        try:
            f = self.grouped['Fragment: {}'.format(self.n_frag)]
            self.n_frag += 1
            return f
        except:
            return None

# %%
def token2features(frag, i):
    token = frag[i][0]

    features = {
        'bias': 1.0,
        'token':token,
        'token.lower()': token.lower(),
        'token.isupper()': token.isupper(),
        'token.istitle()': token.istitle(),
        'token.isdigit()': token.isdigit(),
    }

    return features

def frag2features(frag):
  return [token2features(frag, i) for i in range(len(frag))]
def frag2labels(frag):
  return [label for token, label in frag]

# %%
X_crf = df.drop(['doc'], axis=1)
getter = FragmentGetter(X_crf)
fragments = getter.fragments

X = [frag2features(f) for f in fragments]
y = [frag2labels(f) for f in fragments]

# %%
# Daftar unik dokumen
docs = df['doc'].unique().tolist()

# Menentukan batas dokumen terakhir untuk training (70% dari total dokumen)
train_doc_count = int(len(docs) * 0.7)
train_docs = docs[:train_doc_count]

# Mencari fragment terakhir dari data train
train_df = df[df['doc'].isin(train_docs)]
id_last_frag = train_df['fragment'].unique().tolist()[-1]
last_frag = int(id_last_frag.split(':')[1])

# Memotong data menjadi training dan testing set berdasarkan indeks terakhir
X_train = X[:last_frag+1]
y_train = y[:last_frag+1]
X_test = X[last_frag+1:]
y_test = y[last_frag+1:]

# Menampilkan hasil pemisahan data
print(f"Jumlah sampel dalam training set: {len(X_train)}")
print(f"Jumlah sampel dalam testing set: {len(X_test)}")
# Out:
# Jumlah sampel dalam training set: 8021
# Jumlah sampel dalam testing set: 3252

# %%
crf = sklearn_crfsuite.CRF(
    algorithm='lbfgs',
    c1=0.1,
    c2=0.1,
    max_iterations=100,
    all_possible_transitions=True
)
crf_start = time.time()
crf.fit(X_train, y_train)
crf_end = time.time()
print(f'{(crf_end - crf_start):.2f} Detik.')
# Out:
# 290.24 Detik.

# %%
joblib.dump(crf, '600crf_wordfrom.pkl')
# Out:
# ['600crf_wordfrom.pkl']

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix, classification_report

y_pred= crf.predict(X_test)
y_test_flat = [label for sent in y_test for label in sent]
y_pred_flat = [label for sent in y_pred for label in sent]

# change label to list
y = df.label.values
classes = np.unique(y)
classes = classes.tolist()

# Buat confusion matrix
cm = confusion_matrix(y_test_flat, y_pred_flat, labels=classes)

# Visualisasikan confusion matrix
plt.figure(figsize=(10, 8))
sns.heatmap(cm, annot=True, fmt='d', xticklabels=classes, yticklabels=classes, cmap='Blues')
plt.ylabel('Actual')
plt.xlabel('Predicted')
plt.title('Confusion Matrix')
plt.show()

print(classification_report(y_test_flat, y_pred_flat, labels=classes))
# Out:
#               precision    recall  f1-score   support
#
#       B_ARTV       0.63      0.64      0.63       408
#       B_CRIA       0.89      0.72      0.79       994
#       B_DEFN       0.75      0.18      0.29      3451
#       B_JUDG       0.74      0.80      0.77       629
#       B_JUDP       0.56      0.28      0.37       330
#       B_PENA       0.58      0.34      0.43       149
#       B_PROS       0.93      0.76      0.84       168
#       B_PUNI       0.65      0.56      0.60       200
#       B_REGI       0.74      0.73      0.73       313
#       B_TIMV       0.40      0.08      0.14       166
#       B_VERN       0.98      0.97      0.98       504
#       I_ARTV       0.42      0.59      0.49      4000
#       I_CRIA       0.56      0.33      0.41      1041
#       I_DEFN       0.73      0.22      0.34      8161
#       I_JUDG       0.83      0.81      0.82       994
#       I_JUDP       0.29      0.19      0.23       265
#       I_PENA       0.51      0.29      0.37       823
#       I_PROS       0.93      0.74      0.82       273
#       I_PUNI       0.60      0.70      0.65      1008
#       I_REGI       0.72      0.69      0.71       381
#       I_TIMV       0.44      0.11      0.18       381
#       I_VERN       0.97      0.97      0.97      4563
#            O       0.96      0.99      0.97    356872
#
#     accuracy                           0.95    386074
#    macro avg       0.69      0.55      0.59    386074
# weighted avg       0.94      0.95      0.94    386074

# %%
import eli5
eli5.show_weights(crf, top=5)
# Out:
# 2024-07-11 00:47:47.571206: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-07-11 00:47:47.571377: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-07-11 00:47:47.741937: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
#     <style>
#     table.eli5-weights tr:hover {
#         filter: brightness(85%);
#     }
# </style>
#
#
#
#
#
#
#
#
#
#
#
# <table class="eli5-transition-features" style="margin-bottom: 0.5em;">
#     <thead>
#         <tr>
#             <td>From \ To</td>
#
#                 <th>B_ARTV</th>
#
#                 <th>B_CRIA</th>
#
#                 <th>B_DEFN</th>
#
#                 <th>B_JUDG</th>
#
#                 <th>B_JUDP</th>
#
#                 <th>B_PENA</th>
#
#                 <th>B_PROS</th>
#
#                 <th>B_PUNI</th>
#
#                 <th>B_REGI</th>
#
#                 <th>B_TIMV</th>
#
#                 <th>B_VERN</th>
#
#                 <th>I_ARTV</th>
#
#                 <th>I_CRIA</th>
#
#                 <th>I_DEFN</th>
#
#                 <th>I_JUDG</th>
#
#                 <th>I_JUDP</th>
#
#                 <th>I_PENA</th>
#
#                 <th>I_PROS</th>
#
#                 <th>I_PUNI</th>
#
#                 <th>I_REGI</th>
#
#                 <th>I_TIMV</th>
#
#                 <th>I_VERN</th>
#
#                 <th>O</th>
#
#         </tr>
#     </thead>
#     <tbody>
#
#
#                 <tr>
#                     <th>B_ARTV</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 92.96%)" title="B_ARTV &rArr; B_ARTV">
#                             -2.148
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 99.63%)" title="B_ARTV &rArr; B_CRIA">
#                             -0.032
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.31%)" title="B_ARTV &rArr; B_DEFN">
#                             -0.28
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B_ARTV &rArr; B_JUDG">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B_ARTV &rArr; B_JUDP">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B_ARTV &rArr; B_PENA">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B_ARTV &rArr; B_PROS">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B_ARTV &rArr; B_PUNI">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B_ARTV &rArr; B_REGI">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B_ARTV &rArr; B_TIMV">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 99.42%)" title="B_ARTV &rArr; B_VERN">
#                             -0.061
#                         </td>
#
#                         <td style="background-color: hsl(120, 100.00%, 91.53%)" title="B_ARTV &rArr; I_ARTV">
#                             2.797
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.66%)" title="B_ARTV &rArr; I_CRIA">
#                             -0.2
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 94.13%)" title="B_ARTV &rArr; I_DEFN">
#                             -1.656
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 96.22%)" title="B_ARTV &rArr; I_JUDG">
#                             -0.884
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 96.90%)" title="B_ARTV &rArr; I_JUDP">
#                             -0.665
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 94.64%)" title="B_ARTV &rArr; I_PENA">
#                             -1.452
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 99.39%)" title="B_ARTV &rArr; I_PROS">
#                             -0.066
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.83%)" title="B_ARTV &rArr; I_PUNI">
#                             -0.166
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 96.98%)" title="B_ARTV &rArr; I_REGI">
#                             -0.641
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 95.82%)" title="B_ARTV &rArr; I_TIMV">
#                             -1.02
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 94.88%)" title="B_ARTV &rArr; I_VERN">
#                             -1.361
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 91.43%)" title="B_ARTV &rArr; O">
#                             -2.842
#                         </td>
#
#                 </tr>
#
#                 <tr>
#                     <th>B_CRIA</th>
#
#                         <td style="background-color: hsl(0, 100.00%, 97.41%)" title="B_CRIA &rArr; B_ARTV">
#                             -0.516
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 94.29%)" title="B_CRIA &rArr; B_CRIA">
#                             -1.59
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 97.55%)" title="B_CRIA &rArr; B_DEFN">
#                             -0.476
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 96.90%)" title="B_CRIA &rArr; B_JUDG">
#                             -0.665
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.64%)" title="B_CRIA &rArr; B_JUDP">
#                             -0.206
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 95.52%)" title="B_CRIA &rArr; B_PENA">
#                             -1.125
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00%)" title="B_CRIA &rArr; B_PROS">
#                             0.0
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 94.39%)" title="B_CRIA &rArr; B_PUNI">
#                             -1.552
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 97.90%)" title="B_CRIA &rArr; B_REGI">
#                             -0.382
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 98.99%)" title="B_CRIA &rArr; B_TIMV">
#                             -0.135
#                         </td>
#
#                         <td style="background-color: hsl(0, 100.00%, 100.00
